# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt

# %%
## ## CREATE group sequence with the interval of 5
    # [ 5 - 10 , 11-15 ,  16-20 ,   21-25  ] a
    # append to class  
    # make it reverse huhuhuh


clasS = []
for s in range(46 , 20 , -5):    
    print(f"{s} - {s + 4}")
    sub_clasS = str(s)+"-"+str(s+4)
    clasS.append(sub_clasS)
# print
print(f"\n {clasS}")
# Out:
# 46 - 50
# 41 - 45
# 36 - 40
# 31 - 35
# 26 - 30
# 21 - 25
#
#  ['46-50', '41-45', '36-40', '31-35', '26-30', '21-25']

# %%
#  MEASURE OF POSITION in GROUP DATA v2.0
#  MEASURE OF POSITION in GROUP DATA v2.0
#  MEASURE OF POSITION in GROUP DATA v2.0


        # From raw numbers to insightful comparisons, 
        # Python transforms group data. Calculate positions, 
        # identify trends, and unlock the hidden stories within your datasets
            # large computatino 
            # change datasets 
            # this code are includ validation 


given = [4 , 8, 11 , 9, 12, 6]  
    # this given must match on Class length to generate intervals and patterns



    ## accept argument with longer list or more ! 
    ## accept argument with longer list or more !  
        # you can change these list whether yu wanttttt :> 
        # you can change these list whether yu wanttttt :> 
given_quartile = [1,3]
given_decile = [9 , 7]
given_percentile = []  #  <---- given_quartile, given_decile and given_percentile  can be change by any number you want






a = r'Lb + \left( \frac {\left(\frac{KN}{4||10||100}\right) - CF_{b}}{F_{qk}}\right)i'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.2,0.4 ,'$%s$' %a,size=50,color="green") 
plt.show()

    ## after matching, the argument will return some table need for selecting indexes
    ## after matching, the argument will return some table need for selecting indexes

def match(grop) : 
    grop[['1st', '2nd']] = grop['class_'].str.split('-', expand=True)  
    grop[['1st', '2nd']] = grop[['1st', '2nd']].astype(int)
    grop.drop('2nd' , axis=1 , inplace=True) 
    grop['lowerb'] =  grop['1st'] - 0.5 
    
    # grop['cumfreq'] = grop.groupby('score_')['score_'].transform('size').cumsum()
    grop.sort_values(by='1st', ascending=True, inplace=True)
    grop['cf']= grop['score_'].cumsum() 
    # display(grop)
    return grop


    ## ALL important variable will be calculate here 
    ## ALL important variable will be calculate here 

def main_calcu(KNd_m , cf_before_m , score_selected_m , interval_m , lowerb_selected_m ) :         
    inner = (KNd_m - cf_before_m) / score_selected_m
    results =  lowerb_selected_m + ( inner * interval_m )             
    return results
    # print(results)
    # return results




    ## AFTER returnig match() function these parameter will declare varables base on selected loop
    ## AFTER returnig match() function these parameter will declare varables base on selected loop

def selected_(KNd4, q, KN_type, KN_list, jargon):
    print("\n\n\n") 
    # print("----------------------------------------")   
    # print(f"\n This are from functin {KN_type} : {KNd4}")
    if jargon == 'Q': 
        print(f"FINDING THE Q{ given_quartile[q]} \n")
        
    if jargon == 'D' :
        print(f"FINDING THE D{ given_decile[q]} \n")

    if jargon == 'P': 
        print(f"FINDING THE P{ given_percentile[q]} \n")

    print(f"from group data of : \n \t{clasS} \n")
    print(f"with score dataset of : \n \t{given} \n")
    # if jargon == ''
    
    # print()
    for x in range(group_size -1, -1, -1) :
        group_cf = group['cf'][x]
        # print(f" group_cf \t: \t{group_cf} ") 
        # print("------------------------------")
        if group_cf >=  KNd4: 
            # print("\t\t\t should be stop ! ")                 

            
            print(f"{KN_type} [{q}] \t\t{KNd4}")
            lowerb_selected = group['lowerb'][x]            
            print(f"lower selected(LB) \t \t{lowerb_selected}")
            if KNd4 < group['cf'].min():
                cf_before = group['cf'][x]
            else : 
                cf_before = group['cf'][x+1]                
                
            print(f"cf_before (CFb)\t\t: \t{cf_before}")
            score_selected = group['score_'][x]
            print(f"score selected (FQK) \t: \t{score_selected}")            
            
            interval = group['1st'][0] - group['1st'][1]
            print(f"interval(i) \t\t: \t{interval}")

            # print(4-2)
            
            # def main_calcu(KNd_m , cf_before_m , score_selected_m , interval_m , lowerb_selected_m ) :         
            #     inner = (KNd_m - cf_before_m) / score_selected 
            #     result =  lowerb_selected_m + ( inner * interval_m ) 
            #     return result
                
            main_c = main_calcu(KNd4, cf_before , score_selected , interval , lowerb_selected )

            if jargon == 'Q': 
                print(f"Answer of Q{given_quartile[q]} \t= {main_c}  \n")
                
            if jargon == 'D' :
                # print(f"FINDING THE D{ given_decile[q]} \n")
                print(f"Answer of D{given_decile[q]} \t= {main_c}  \n")
        
            if jargon == 'P': 
                # print(f"FINDING THE P{ given_percentile[q]} \n")
                print(f"Answer of P{ given_percentile[q]} \t= {main_c}  \n")
            
            # print(f"{gin}  \t\t{main_c}")
            
                        
            break     
            
        # else :             
            # print(" \n\n elseeeeeee ")
            # print(f"{group_cf} are less than {KN_list[q]}") 

        
if len(clasS) == len(given) :
    group = pd.DataFrame({
        'class_': clasS  , 
        'score_' : given          
    }) 
    
    match(group) 
    display(group)    
    group_size = group.index.size
    
    print("----------------------------------------------- \n\n\n")
    
    right_aligned = 'QUARTILE CALCULATION'.rjust(20) 
    print(right_aligned)

    
    if given_quartile == [] :
        print(f"\n THE QUARTILE LIST ARE EMPTY  \n\n") 
    else :      
        
        for validate_quartile in given_quartile :        
            ## validate if given quartile are okay             
            if not validate_quartile > 4 : 
                KNd4_Qlist = [] 
                for q in range(0,len(given_quartile) ):
                    type_4 = 'KNd4_Quartile'
                    sum_score = group['score_'].sum()
                    KNd4_Q = ((given_quartile[q] * sum_score/4))               
                    # print(f" KNd4_Q {given_quartile[q]} \t: \t{KNd4_Q}") 
                    KNd4_Qlist.append(KNd4_Q)   
                    jargon = 'Q'
                    selected_(KNd4_Q , q, type_4, KNd4_Qlist, jargon)     
            
                    
                break 
            else : 
                print("invalid to calculate quartile pls input only [1, 2, 3, 4] in this list")
        


    print("----------------------------------------------- \n\n\n")    
    right_aligned = 'DECILE CALCULATION'.rjust(20) 
    print(right_aligned)
    
    if given_decile == [] : 
        print(f" \n THE GIVEN DECILE ARE EMPTY \n\n")
    else :          
        # print('this is valid decile') 
        
        for validate_decile in given_decile :   
            # print('this is valid 2') 
            if validate_decile < 10 :                     
                # print('validiitigy check')            
                KNd10_Dlist = []
                for dd in range(0,len(given_decile)) :            
                    # print()
                    type_10 = 'KNn10_Decile' 
                    sum_score = group['score_'].sum() 
                    KNd10_D = ((given_decile[dd] * sum_score) /10)        
                    KNd10_Dlist.append(KNd10_D)
                    jargon = 'D'
                    
                    selected_(KNd10_D , dd, type_10, KNd10_Dlist , jargon)
                    # print(f"KNd10_D \t: {} \t {KNd10_D}")         
                break
                # print("invalid to calculate quartile pls input only [1, 2, 3, 4] in this list")                 
            else : 
                print("invalid to calculate quartile pls input only [1-10] in this list")
                # break 
    
    print("----------------------------------------------- \n\n\n")
    right_aligned = 'PERCENTILE CALCUTION'.rjust(20) 
    print(f"{right_aligned} \n\n")
    

    if given_percentile == [] : 
        print(f" \n\n THE GIVEN PERCENTILE ARE EMPTY \n\n")
    else :          
        # print('this is valid decile')         
        for validate_percentile in given_percentile :   
            # print('this is valid 2') 
            if not validate_percentile > 100 :                     
                # print('validiitigy check')            
                KNd100_Plist = []
                for pp in range(0,len(given_percentile)) :            
                    # print()
                    type_100 = 'KNn100_Percentile' 
                    
                    type_jargon ='P'
                    sum_score = group['score_'].sum() 
                    # print(f"\t\t THIS ARE SUM SCORE {sum_score} \n")  
                    
                    KNd100_P = (given_percentile[pp] * sum_score / 100 )        
                    KNd100_Plist.append(KNd100_P)
                    
                    selected_(KNd100_P , pp, type_100, KNd100_Plist, type_jargon)   

                break
                # print("invalid to calculate quartile pls input only [1, 2, 3, 4] in this list")                 
            else : 
                print("invalid to calculate quartile pls input only [1 - 100] in this list")



    # if given_percentile == [] : 
    #     print(f" \n\n Percentile are empty \n\n")
    # else : 
    #     KNd100_Plist = []
    #     for pp in range(0,len(given_percentile)) :            
    #         # print()
    #         sum_score = group['score_'].sum()
    #         type_100 = 'KNn100_Percentile'
    #         KNd100_P = ((given_percentile[pp] * sum_score ) /100)        
    #         print(f"this are  \t\t{KNd100_P} ")
    #         print(f"this are  \t\t{type_100} ")
    #         # print(f"this are  \t\t{su} ")
            
            
    #         KNd100_Plist.append(KNd100_P)
    #         fix_bug(KNd100_P , pp , type_100, KNd100_Plist)
    #         # selected_(KNd100_P , pp , type_100, KNd100_Plist )
    #         # print(f"KNd10_D \t: {} \t {KNd10_D}") 
    #     print(f"this are PLIST \t\t{KNd100_Plist}")
# Out:
#   class_  score_  1st  lowerb  cf
# 5  21-25       6   21    20.5   6
# 4  26-30      12   26    25.5  18
# 3  31-35       9   31    30.5  27
# 2  36-40      11   36    35.5  38
# 1  41-45       8   41    40.5  46
# 0  46-50       4   46    45.5  50
# -----------------------------------------------
#
#
#
# QUARTILE CALCULATION
#
#
#
#
# FINDING THE Q1
#
# from group data of :
#  	['46-50', '41-45', '36-40', '31-35', '26-30', '21-25']
#
# with score dataset of :
#  	[4, 8, 11, 9, 12, 6]
#
# KNd4_Quartile [0] 		12.5
# lower selected(LB) 	 	25.5
# cf_before (CFb)		: 	6
# score selected (FQK) 	: 	12
# interval(i) 		: 	5
# Answer of Q1 	= 28.208333333333332
#
#
#
#
#
# FINDING THE Q3
#
# from group data of :
#  	['46-50', '41-45', '36-40', '31-35', '26-30', '21-25']
#
# with score dataset of :
#  	[4, 8, 11, 9, 12, 6]
#
# KNd4_Quartile [1] 		37.5
# lower selected(LB) 	 	35.5
# cf_before (CFb)		: 	27
# score selected (FQK) 	: 	11
# interval(i) 		: 	5
# Answer of Q3 	= 40.27272727272727
#
# ...

# %% [markdown]
# ## THIS ARE MY SCRATCH AND PROGRESS WITH BUGS :>

# %%
# group = 


## CREATE group sequence with the interval of 5
    # [ 5 - 10 , 11-15 ,  16-20 ,   21-25  ] 
    
for x in range(5, 30 , 5):
    if x == 5:
        print(f"{x} - {x + 5 } ") 
    else : 
        print(f"{x + 1 } - {x + 5}")

## sampoink code 
# -- -----------------------------

# %%
# -----------------------

## ## CREATE group sequence with the interval of 5
    ## code Challenge :  [ 5 - 10 , 11-15 ,  16-20 ,   21-25  ] a
    # append to class 

classx = []
for x in range(5, 100, 5):
    if x == 5:
        # print(f"{x} - {x + 5 } ")  
        sub_class = str(x)+"-"+str(x+5)
        classx.append(sub_class)                
    else : 
        # print(f"{x + 1 } - {x + 5}")
        sub_class = str(x+1)+"-"+str(x+5)
        classx.append(sub_class)
print(classx)
print(len(classx))
# 
#

# %%
## ## CREATE group sequence with the interval of 5
    # [ 5 - 10 , 11-15 ,  16-20 ,   21-25  ] a
    # append to class  
    # make it reverse huhuhuh


clasS = []
for s in range(46 , 20 , -5):    
    print(f"{s} - {s + 4}")
    sub_clasS = str(s)+"-"+str(s+4)
    clasS.append(sub_clasS)

print(clasS)
# Out:
# 46 - 50
# 41 - 45
# 36 - 40
# 31 - 35
# 26 - 30
# 21 - 25
# ['46-50', '41-45', '36-40', '31-35', '26-30', '21-25']

# %%
# def breaks() : 
#     print(" The lengths of list 'clasS' and 'given' are unmatched. \n"* 3) 


## addint to functino to fix if statement in 1st validation 
## addint to functino to fix if statement in 1st validation 
def match(grops) : 

    # grops['sampoink'] = grops['score_'] - 0.3
    # display(grops) 
    # return grops

    grops[['1st', '2nd']] = grops['class_'].str.split('-', expand=True)  
    grops[['1st', '2nd']] = grops[['1st', '2nd']].astype(int)
    grops.drop('2nd' , axis=1 , inplace=True) 
    grops['lowerb'] =  grops['1st'] - 0.5 
    
        # group['cumfreq'] = group.groupby('score_')['score_'].transform('size').cumsum()
    
    grops.sort_values(by='1st', ascending=True, inplace=True)
    grops['cf']= grops['score_'].cumsum() 

    return grops


# def calcu_decile () : 

    

    # display (grops)     

    
    # # print("Does it work??")

            ### KN / 4 
    # sum_score = group['score_'].sum() 
    # KNd4 = ((given_quartile * sum_score)/4)   
    # if KNd4 > 


## given should match in len to len

given = [4 , 8, 11 , 9, 12, 6]
# accept argument with longer list or more ! 
given_quartile = 1 
# given_decile = []
# giveb_percentile = []

## if stament validating lenght of two list and must match both lenght

if len(clasS) == len(given) :
    group = pd.DataFrame({
        'class_': clasS  , 
        'score_' : given  
        
    }) 
    
    match(group) 
        
    # if given_percentil == [] :
            
    sum_score = group['score_'].sum() 
    KNd4 = ((given_quartile * sum_score)/4)   
    print(f" KNd4 \t: \t{KNd4}") 


    group_size = group.index.size

    for x in range(group_size -1, -1, -1) :
        group_cf = group['cf'][x] 
        if group_cf > KNd4: 
            # print("should be stop")     

            lowerb_selected = group['lowerb'][x]
            print(f"lower selected \t: \t{lowerb_selected}")
            
            cf_before = group['cf'][x+1]
            print(f"cf_before \t: \t{cf_before}") 
            
            score_selected = group['score_'][x]
            print(f"score selected  : \t{score_selected}")
            
            FreqQK = group['score_'][x]
            print(f"FQk \t\t: \t{FreqQK}")
    
            interval = group['1st'][0] - group['1st'][1]
            print(f"interval \t: \t{interval}")

            
            
            break 
        else : 
            print(f"{group_cf} are greater than {KNd4} \n") 

    display(group) 
    # print(group.dtypes) 
    # display(group)

    # range
    group.loc[0]
    # print(len(group['cf']))    
            
else :
    print(" The lengths of list 'clasS' and 'given' are unmatched. \n"* 3) 
    
    # exit()
    # breaks()        
    # break
# group

# df['cumsum_col1'] = df['col1'].cumsum()

# %%
keyen = 13
group_size = group.index.size

for x in range(group_size -1, -1, -1) :
    group_cf = group['cf'][x] 
    if group_cf > keyen: 
        # print("should be stop")     

        lowerb_selected = group['lowerb'][x]
        print(f"lower selected \t: \t{lowerb_selected}")
        
        cf_before = group['cf'][x+1]
        print(f"cf_before \t: \t{cf_before}") 
        
        score_selected = group['score_'][x]
        print(f"score selected  : \t{score_selected}")
        
        FreqQK = group['score_'][x]
        print(f"FQk \t\t: \t{FreqQK}")

        interval = group['1st'][0] - group['1st'][1]
        print(f"interval \t: \t{interval}")
        
        
        break 
    else : 
        print(f"{group_cf} are greater than {keyen} \n")

# %%
# print(group['cf'].int.len())
# count(group)


# trial mathching
# keyen = 13

# def pepsi(ceef) :
#     if ceef > keyen :
#         print(f"{ceef} are greater than keyen ")
#         # return  "shitnes"
#         # return "gretir"
#     else : 
#         print(f"{ceef} are less than keyen")
        # return "less tans"
    

# var_1 = group['cf'].apply(pepsi)

# print(var_1) 
# for x in range(group.index.size) 
    # group.loc[] 


# ------------------------------
group_size = group.index.size

for x in range(group_size -1, -1, -1) :
    group_cf = group['cf'][x] 
    if group_cf > keyen: 
        # print("should be stop")     

        lowerb_selected = group['lowerb'][x]
        
        print(f"lower selected \t: \t{lowerb_selected}")
        cf_before = group['cf'][x+1]
        print(f"cf_before \t: \t{cf_before}")
        score_selected = group['score_'][x]
        print(f"score selected  : \t{score_selected}")
        
        break 
    else : 
        print(f"{group_cf} are greater than {keyen} \n") 
    
# ------------------------------------------------------- 
    # print(x)
    # group.loc
    # group.loc[X, "cf" ]

# print(group['cf'][x])

# print(group.index.size) 
# group.loc[0, "cf" ]

# %%
# def pepsi(age): 

    
#     if age > 8 : 
#         return "greatir"
#     else :
#         return "falsi"

# group["trial"] = group['score_'].apply(pepsi)

# %%
# def breaks() : 
#     print(" The lengths of list 'clasS' and 'given' are unmatched. \n"* 3) 


## addint to functino to fix if statement in 1st validation 
## addint to functino to fix if statement in 1st validation 

# -----------------------------

def match() : 
 
    group[['1st', '2nd']] = group['class_'].str.split('-', expand=True)  
    group[['1st', '2nd']] = group[['1st', '2nd']].astype(int)
    group.drop('2nd' , axis=1 , inplace=True) 
    group['lowerb'] =  group['1st'] - 0.5 
    
    # group['cumfreq'] = group.groupby('score_')['score_'].transform('size').cumsum()
    group.sort_values(by='1st', ascending=True, inplace=True)
    group['cf']= group['score_'].cumsum() 

    display(group)


# ------------------------------- 
    # return group
    # group['cf']
    
    # sum_score = group['score_'].sum() 
    # print(group)
    # print("Does it work??")
    # print(sum_score) 
    
    # KN / 4
    # KNd4 = ((given_quartile * sum_score)/4)   
    # if KNd4 >


## given should match in len to len

given = [4 , 8, 11 , 9, 12, 8]
# accept argumento with longer list or more ! 
given_quartile = 1


## if stament validating lenght of two list and must match both lenght

if len(clasS) == len(given) :
    group = pd.DataFrame({
        'class_': clasS  , 
        'score_' : given  
        
    }) 
    match()
    
    # group[['1st', '2nd']] = group['class_'].str.split('-', expand=True)  
    # group[['1st', '2nd']] = group[['1st', '2nd']].astype(int)
    # group.drop('2nd' , axis=1 , inplace=True) 
    # group['lowerb'] =  group['1st'] - 0.5 
    
    # # group['cumfreq'] = group.groupby('score_')['score_'].transform('size').cumsum()
    # group.sort_values(by='1st', ascending=True, inplace=True)
    # group['cf']= group['score_'].cumsum() 

    # group
    # display(group)
    # print("does it work ?")
else :
    print(" The lengths of list 'clasS' and 'given' are unmatched. \n"* 3) 
    
# group.info

# %%
## List attempt condition
## List attempt condition 

given = [4 , 8, 11 , 9, 12, 6]
# accept argument with longer list or more ! 
given_quartile = [1, 3]
given_decile = []
# giveb_percentile = []


def selected_(KNd4, q):
    print("\n\n\n")
    print("----------------------------------------")
    print(f"\t This are from functin KNd4_Q : {KNd4}s")
   
    for x in range(group_size -1, -1, -1) :
        group_cf = group['cf'][x]
        # print(f" group_cf \t: \t{group_cf} ") 
        # print("------------------------------")
        if group_cf >  KNd4: 
            # 
            # print("should be stop")    
            print("\n\n\n\n")
            print(f"KNd4_Q {q} \t\t: \t{KNd4}")
            lowerb_selected = group['lowerb'][x]            
            print(f"lower selected \t\t: \t{lowerb_selected}")
            cf_before = group['cf'][x+1]
            print(f"cf_before \t\t: \t{cf_before}")
            score_selected = group['score_'][x]
            print(f"score selected (FQK) \t: \t{score_selected}")
            break     
        else : 
            print(f"{group_cf} are greater than {KNd4_Qlist[q]}") 
if len(clasS) == len(given) :
    group = pd.DataFrame({
        'class_': clasS  , 
        'score_' : given          
    }) 
    match(group) 
    display(group)    
    if given_quartile == [] :
        print(f"quartigle are empty \n\n") 
    else :        
        KNd4_Qlist = []
        for q in range(0,len(given_quartile) ):
            ##print(q
            KNd4_Q = ((given_quartile[q] * sum_score/4))               
            # print(f" KNd4_Q {given_quartile[q]} \t: \t{KNd4_Q}") 
            KNd4_Qlist.append(KNd4_Q)  

            selected_(KNd4_Q , q)
            # group_size = group.index.size
            # group_size = group.index.size
            
            # for x in range(group_size -1, -1, -1) :
            #     group_cf = group['cf'][x] 
            #     print(f" group_cf \t: \t{group_cf}")
            #     print("------------------------------")
            #     if group_cf >  KNd4_Qlist[q]: 
            #         print("should be stop")     
                    
            #         lowerb_selected = group['lowerb'][x]
                    
            #         print(f"lower selected \t: \t{lowerb_selected}")
            #         cf_before = group['cf'][x+1]
            #         print(f"cf_before \t: \t{cf_before}")
            #         score_selected = group['score_'][x]
            #         print(f"score selected  : \t{score_selected}")
            #         print("\n\n\n")
            #         print(f"{}")                        
                    # break 
                # else : 
                #     print(f"{group_cf} are greater than {KNd4_Qlist[q]} \n")                             



    
        # print(f"\n KNd4_Q list \t: \t{KNd4_Qlist}") 


            #if KNd4_Q > len
            
    if given_decile == [] :
        print(f" \n\n Decile are empty \n\n")
    else : 
        KNd10_D = ((given_decile * sum_score/10))        
        
        # print(f"KNd10_D \t: {} \t {KNd10_D}")

# %%
## List attempt condition
## List attempt condition 

given = [4 , 8, 11 , 9, 12, 6]
# accept argument with longer list or more ! 
given_quartile = [1,2]
given_decile = [3 , 2]


def match(grop) : 
 
    grop[['1st', '2nd']] = grop['class_'].str.split('-', expand=True)  
    grop[['1st', '2nd']] = grop[['1st', '2nd']].astype(int)
    grop.drop('2nd' , axis=1 , inplace=True) 
    grop['lowerb'] =  grop['1st'] - 0.5 
    
    # grop['cumfreq'] = grop.groupby('score_')['score_'].transform('size').cumsum()
    grop.sort_values(by='1st', ascending=True, inplace=True)
    grop['cf']= grop['score_'].cumsum() 

    return grop
    # display(grop)
    


def selected_(KNd4, q, KN_type ):  # KN_list
    print("\n\n\n")
    # print("----------------------------------------")    
    print(f"\n This are from functin {KN_type} : {KNd4}")
    for x in range(group_size -1, -1, -1) :
        group_cf = group['cf'][x]
        # print(f" group_cf \t: \t{group_cf} ") 
        # print("------------------------------")
        if group_cf >=  KNd4: 
            # 
            print("\t\t\t should be stop ! ")     
            
            print("\n\n") 
            print(f"{KN_type} {q} \t\t: \t{KNd4}")
            lowerb_selected = group['lowerb'][x]            
            print(f"lower selected \t\t: \t{lowerb_selected}")
            cf_before = group['cf'][x+1]
            print(f"cf_before \t\t: \t{cf_before}")
            score_selected = group['score_'][x]
            print(f"score selected (FQK) \t: \t{score_selected}")
            break     
        else :             
            # print(" \n\n elseeeeeee ")
            # print(f"{group_cf} are less than {KN_list[q]}") 

        
if len(clasS) == len(given) :
    group = pd.DataFrame({
        'class_': clasS  , 
        'score_' : given          
    }) 

    
    match(group) 
    print("\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n")
    display(group)    
    group_size = group.index.size
    
    print("----------------------------------------------- \n\n\n")
    
    # print("----------------------------------------------- \n\n\n")    
    right_aligned = 'QUARTILE CALCULATION'.rjust(20) 
    print(right_aligned)

    
    if given_quartile == [] :
        print(f"THE QUARTILE LIST ARE EMPTY  \n\n") 
    else :                
        for validate_quartile in given_quartile :        
            ## validate if given quartile are okay 
            ## validate if given quartile are okay     
            if not validate_quartile > 4 : 
                # KNd4_Qlist = [] 
                # for q in range(0,len(given_quartile) ):
                #     type = 'KNd4_Quartile'
                #     sum_score = group['score_'].sum()
                #     KNd4_Q = ((given_quartile[q] * sum_score/4))               
                #     # print(f" KNd4_Q {given_quartile[q]} \t: \t{KNd4_Q}") 
                #     KNd4_Qlist.append(KNd4_Q)   
                #     selected_(KNd4_Q , q, type, KNd4_Qlist)     
                    
                break 
            else : 
                print("invalid to calculate quartile pls input only [1, 2, 3, 4] in this list")
        


    print("----------------------------------------------- \n\n\n")    
    right_aligned = 'DECILE CALCULATION'.rjust(20) 
    print(right_aligned)
    
    if given_decile == [] : 
        print(f" \n\n Decile are empty \n\n")
    else :          
        KNd10_Dlist = []
        for dd in range(0,len(given_decile)) :            
            # print()
            type = 'KNn10_Decile' 
            sum_score = group['score_'].sum()
            KNd10_D = ((given_decile[dd] * sum_score/10))        
            KNd10_Dlist.append(KNd10_D)
            selected_(KNd10_D , dd, type, KNd10_Dlist )
            # print(f"KNd10_D \t: {} \t {KNd10_D}") 
    
    print("----------------------------------------------- \n\n\n")
    right_aligned = 'PERCENTILE CALCUTION'.rjust(20) 
    print(right_aligned)

    if given_percentile == [] : 
        print(f" \n\n Percentile are empty \n\n")
    else : 
        KNd100_Plist = []
        for dd in range(0,len(given_percentile)) :            
            # print()
            type = 'KNn10_Decile'
            KNd100_P = ((given_percentile[dd] * sum_score/100))        
            KNd100_Plist.append(KNd100_P)
            selected_(KNd100_P , dd, type)
            # print(f"KNd10_D \t: {} \t {KNd10_D}")

# %%
lest = [2 , 4 , 6 , 3]


# if 5 > x in lest :
    # print("failed")

for lest_x in lest:
    if lest_x > 4 :
        print(f" this {lest_x} are greater than ")
    else : 
        print(F"haha less than ")
    # print(lest_x)

# %%
## List attempt condition
## List attempt condition 

given = [4 , 8, 11 , 9, 12, 6]
# accept argument with longer list or more ! 
given_quartile = []
given_decile = []
# given_percentile = [10,40]
given_percentile = [10 , 60]

def match(grop) : 
 
    grop[['1st', '2nd']] = grop['class_'].str.split('-', expand=True)  
    grop[['1st', '2nd']] = grop[['1st', '2nd']].astype(int)
    grop.drop('2nd' , axis=1 , inplace=True) 
    grop['lowerb'] =  grop['1st'] - 0.5 
    
    # grop['cumfreq'] = grop.groupby('score_')['score_'].transform('size').cumsum()
    grop.sort_values(by='1st', ascending=True, inplace=True)
    grop['cf']= grop['score_'].cumsum() 

    return grop
    # display(grop)
    


def selected_(KNd4, q, KN_type):
    print("\n\n\n")
    # print("----------------------------------------")    
    print(f"\n This are from functin {KN_type} : {KNd4}")
    for x in range(group_size -1, -1, -1) :
        group_cf = group['cf'][x]
        # print(f" group_cf \t: \t{group_cf} ") 
        # print("------------------------------")
        if group_cf >=  KNd4: 
            # 
            print("\t\t\t should be stop ! ")                 
            print("\n\n") 
            print(f"{KN_type} {q} \t\t: \t{KNd4}")
            lowerb_selected = group['lowerb'][x]            
            print(f"lower selected \t\t: \t{lowerb_selected}")
            cf_before = group['cf'][x+1]
            print(f"cf_before \t\t: \t{cf_before}")
            score_selected = group['score_'][x]
            print(f"score selected (FQK) \t: \t{score_selected}")
            break     
        else :             
            # print(" \n\n elseeeeeee ")
            print(f"{group_cf} are less than {KN_list[q]}") 

        
if len(clasS) == len(given) :
    group = pd.DataFrame({
        'class_': clasS  , 
        'score_' : given          
    }) 
    
    match(group) 
    # print("\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n")
    # print("\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n")
    # print("\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n")
    # print("\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n")
    # print("\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n")
    # print("\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n")
    display(group)    
    group_size = group.index.size
    
    print("----------------------------------------------- \n\n\n")
    
    # print("----------------------------------------------- \n\n\n")    
    right_aligned = 'QUARTILE CALCULATION'.rjust(20) 
    print(right_aligned)

    
    if given_quartile == [] :
        print(f"THE QUARTILE LIST ARE EMPTY  \n\n") 
    else :                
        for validate_quartile in given_quartile :        
            ## validate if given quartile are okay 
            ## validate if given quartile are okay     
            if not validate_quartile > 4 : 
                KNd4_Qlist = [] 
                for q in range(0,len(given_quartile) ):
                    type = 'KNd4_Quartile'
                    sum_score = group['score_'].sum()
                    KNd4_Q = ((given_quartile[q] * sum_score/4))               
                    # print(f" KNd4_Q {given_quartile[q]} \t: \t{KNd4_Q}") 
                    KNd4_Qlist.append(KNd4_Q)   
                    selected_(KNd4_Q , q, type, KNd4_Qlist)     
                
                break 
            else : 
                print("invalid to calculate quartile pls input only [1, 2, 3, 4] in this list")
        


    print("----------------------------------------------- \n\n\n")    
    right_aligned = 'DECILEee CALCULATION'.rjust(20) 
    print(right_aligned)
    
    if given_decile == [] : 
        print(f" \n\n Deceile are empty \n\n")
    else :          
        print('this is valid decile') 
        
        for validate_decile in given_decile :   
            # print('this is valid 2') 
            if validate_decile < 10 :                     
                # print('validiitigy check')            
                KNd10_Dlist = []
                for dd in range(0,len(given_decile)) :            
                    # print()
                    type = 'KNn10_Decile' 
                    sum_score = group['score_'].sum()
                    KNd10_D = ((given_decile[dd] * sum_score) /10)        
                    KNd10_Dlist.append(KNd10_D)
                    selected_(KNd10_D , dd, type, KNd10_Dlist )
                    # print(f"KNd10_D \t: {} \t {KNd10_D}")         
                break
                # print("invalid to calculate quartile pls input only [1, 2, 3, 4] in this list")                 
            else : 
                print("invalid to calculate quartile pls input only [1, 2, 3, 4] in this list")
                # break 
            
    print("----------------------------------------------- \n\n\n")
    right_aligned = 'PERCENTILE CALCUTION'.rjust(20) 
    print(right_aligned)

    if given_percentile == [] : 
        print(f" \n\n DECILE are empty \n\n")
    else :          
        print('this is valid decile') 
        
        for validate_percentile in given_percentile :   
            # print('this is valid 2') 
            if validate_percentile <= 100 :                     
                # print('validiitigy check')            
                KNd100_Plist = []
                for dd in range(0,len(given_percentile)) :            
                    # print()
                    type = 'KNn100_Percentile' 
                    sum_score = group['score_'].sum()
                    print(f"\t\t THIS ARE SUM SCORE {sum_score} \n")
                    print(f"\t\t THIS ARE G x S \t{given_percentile[dd] * sum_score} \n")
                    # print()
                    # KNd100_P = (given_percentile[dd] * sum_score / 100)        
                    KNd100_Plist.append(KNd100_P)
                    print(f" \t\t\t list = {KNd100_Plist} ")
                    selected_(KNd100_P , dd, type)
                    # print(f"KNd100_P \t: {} \t {KNd100_P}")         
                break
                # print("invalid to calculate quartile pls input only [1, 2, 3, 4] in this list")                 
            else : 
                print("invalid to calculate quartile pls input only [1, 2, 3, 4] in this list")



    

    # if given_percentile == [] : 
    #     print(f" \n\n Percentile are empty \n\n")
    # else : 
    #     KNd100_Plist = []
    #     for pp in range(0,len(given_percentile)) :            
    #         # print()
    #         sum_score = group['score_'].sum()
    #         type_100 = 'KNn100_Percentile'
    #         KNd100_P = ((given_percentile[pp] * sum_score ) /100)        
    #         print(f"this are  \t\t{KNd100_P} ")
    #         print(f"this are  \t\t{type_100} ")
    #         # print(f"this are  \t\t{su} ")
            
            
    #         KNd100_Plist.append(KNd100_P)
    #         fix_bug(KNd100_P , pp , type_100, KNd100_Plist)
    #         # selected_(KNd100_P , pp , type_100, KNd100_Plist )
    #         # print(f"KNd10_D \t: {} \t {KNd10_D}") 
    #     print(f"this are PLIST \t\t{KNd100_Plist}")

# %%
tril = [3]

if tril == [] : 
    print("valid")

for treks in tril :
    print(treks)
    
    # print('heys')
    # print(treks)

# %%
given_percentile = [30 , 29 ]

display(group)
# def fix_bug(KNd4, q, KN_type, KN_list):
def fix_bug(KNd4, q, KN_type, KN_list ):
    print("\n\n\n")
    # print("----------------------------------------")    
    print(f"\n This are from functin {KN_type} : {KNd4}")
    for x in range(group_size -1, -1, -1) :
        
        group_cf = group['cf'][x]
        print(f" group_cf \t\t: \t{group_cf} ") 
        # print("------------------------------")
        if group_cf >= KNd4: 
        #  
            # print("\t\t\t should be stop ! ")                 
            print("\n\n") 
            print(f"{KN_type} {q} \t\t: \t{KNd4}")
            lowerb_selected = group['lowerb'][x]            
            print(f"lower selected \t\t: \t{lowerb_selected}")
            cf_before = group['cf'][x+1]
            print(f"cf_before \t\t: \t{cf_before}")
            score_selected = group['score_'][x]
            print(f"score selected (FQK) \t: \t{score_selected}")
            break     
        else :             
            # print('this is fassie')
            print(f"{group_cf} are less than {KN_list[q]}") 


KNd100_Plist = []
for pp in range(0 , len(given_percentile)) :            
    # print()
    sum_score = group['score_'].sum()
    type = 'KNn10_Decile'
    # KNd100_P = ((given_percentile[pp] * sum_score ) /100)        
    KNd100_P = (given_percentile[pp] * sum_score / 100)        
    print(f"KNd100_P \t\t: \t{KNd100_P}")     
    print(f"pp  \t\t\t: \t{pp}") 
        
    KNd100_Plist.append(KNd100_P)
    fix_bug(KNd100_P , pp , type, KNd100_Plist)
print(KNd100_Plist)
# Out:
#   class_  score_  1st  lowerb  cf
# 5  21-25       6   21    20.5   6
# 4  26-30      12   26    25.5  18
# 3  31-35       9   31    30.5  27
# 2  36-40      11   36    35.5  38
# 1  41-45       8   41    40.5  46
# 0  46-50       4   46    45.5  50
# KNd100_P 		: 	15.0
# pp  			: 	0
#
#
#
#
#
#  This are from functin KNn10_Decile : 15.0
#  group_cf 		: 	6
# 6 are less than 15.0
#  group_cf 		: 	18
#
#
#
# KNn10_Decile 0 		: 	15.0
# lower selected 		: 	25.5
# cf_before 		: 	6
# score selected (FQK) 	: 	12
# KNd100_P 		: 	14.5
# pp  			: 	1
#
#
#
#
#
#  This are from functin KNn10_Decile : 14.5
#  group_cf 		: 	6
# 6 are less than 14.5
#  group_cf 		: 	18
#
#
#
# KNn10_Decile 1 		: 	14.5
# lower selected 		: 	25.5
# cf_before 		: 	6
# score selected (FQK) 	: 	12
# [15.0, 14.5]

# %%
#  MEASURE OF POSITION in GROUP DATA v2.0

## List attempt condition
## List attempt condition 



given = [4 , 8, 11 , 9, 12, 6]
## accept argument with longer list or more ! 
## accept argument with longer list or more ! 
given_quartile = []
given_decile = [1, 3]
given_percentile = [10,40]
given_percentile = []




def match(grop) : 
 
    grop[['1st', '2nd']] = grop['class_'].str.split('-', expand=True)  
    grop[['1st', '2nd']] = grop[['1st', '2nd']].astype(int)
    grop.drop('2nd' , axis=1 , inplace=True) 
    grop['lowerb'] =  grop['1st'] - 0.5 
    
    # grop['cumfreq'] = grop.groupby('score_')['score_'].transform('size').cumsum()
    grop.sort_values(by='1st', ascending=True, inplace=True)
    grop['cf']= grop['score_'].cumsum() 

    return grop
    # display(grop)
    


def selected_(KNd4, q, KN_type, KN_list, jargon):
    print("\n\n\n") 
    # print("----------------------------------------")   
    # print(f"\n Q{ }")
    # print(f"\n This are from functin {KN_type} : {KNd4}")
    if jargon == 'Q': 
        print(f"FINDING THE Q{ given_quartile[q]} \n")
        
    if jargon == 'D' :
        print(f"FINDING THE D{ given_decile[q]} \n")

    if jargon == 'P': 
        print(f"FINDING THE P{ given_percentile[q]} \n")

    print(f"from group data of : \n \t{clasS} \n")
    print(f"from score dataset of : \n \t{given} \n")
    # if jargon == ''
    

    # print()
    
    for x in range(group_size -1, -1, -1) :
        group_cf = group['cf'][x]
        # print(f" group_cf \t: \t{group_cf} ") 
        # print("------------------------------")
        if group_cf >=  KNd4: 
            # print("\t\t\t should be stop ! ")                 
            # print("\n") 
            print(f"{KN_type} {q}  \t\t{KNd4}")
            lowerb_selected = group['lowerb'][x]            
            print(f"lower selected \t\t: \t{lowerb_selected}")
            if KNd4 < group['cf'].min():
                cf_before = group['cf'][x]
            else : 
                cf_before = group['cf'][x+1]                
                
            print(f"cf_before \t\t: \t{cf_before}")
            score_selected = group['score_'][x]
            print(f"score selected (FQK) \t: \t{score_selected}")
            break     
            
        # else :             
            # print(" \n\n elseeeeeee ")
            # print(f"{group_cf} are less than {KN_list[q]}") 

        
if len(clasS) == len(given) :
    group = pd.DataFrame({
        'class_': clasS  , 
        'score_' : given          
    }) 
    
    match(group) 
    display(group)    
    group_size = group.index.size
    
    print("----------------------------------------------- \n\n\n")
    
    right_aligned = 'QUARTILE CALCULATION'.rjust(20) 
    print(right_aligned)

    
    if given_quartile == [] :
        print(f"\n THE QUARTILE LIST ARE EMPTY  \n\n") 
    else :      
        
        for validate_quartile in given_quartile :        
            ## validate if given quartile are okay             
            if not validate_quartile > 4 : 
                KNd4_Qlist = [] 
                for q in range(0,len(given_quartile) ):
                    type_4 = 'KNd4_Quartile'
                    sum_score = group['score_'].sum()
                    KNd4_Q = ((given_quartile[q] * sum_score/4))               
                    # print(f" KNd4_Q {given_quartile[q]} \t: \t{KNd4_Q}") 
                    KNd4_Qlist.append(KNd4_Q)   
                    jargon = 'Q'
                    selected_(KNd4_Q , q, type_4, KNd4_Qlist, jargon)     
                
                break 
            else : 
                print("invalid to calculate quartile pls input only [1, 2, 3, 4] in this list")
        


    print("----------------------------------------------- \n\n\n")    
    right_aligned = 'DECILE CALCULATION'.rjust(20) 
    print(right_aligned)
    
    if given_decile == [] : 
        print(f" \n THE GIVEN DECILE ARE EMPTY \n\n")
    else :          
        # print('this is valid decile') 
        
        for validate_decile in given_decile :   
            # print('this is valid 2') 
            if validate_decile < 10 :                     
                # print('validiitigy check')            
                KNd10_Dlist = []
                for dd in range(0,len(given_decile)) :            
                    # print()
                    type_10 = 'KNn10_Decile' 
                    sum_score = group['score_'].sum() 
                    KNd10_D = ((given_decile[dd] * sum_score) /10)        
                    KNd10_Dlist.append(KNd10_D)
                    jargon = 'D'
                    
                    selected_(KNd10_D , dd, type_10, KNd10_Dlist , jargon)
                    # print(f"KNd10_D \t: {} \t {KNd10_D}")         
                break
                # print("invalid to calculate quartile pls input only [1, 2, 3, 4] in this list")                 
            else : 
                print("invalid to calculate quartile pls input only [1-10] in this list")
                # break 
    
    print("----------------------------------------------- \n\n\n")
    right_aligned = 'PERCENTILE CALCUTION'.rjust(20) 
    print(f"{right_aligned} \n\n")
    

    if given_percentile == [] : 
        print(f" \n\n THE GIVEN PERCENTILE ARE EMPTY \n\n")
    else :          
        # print('this is valid decile')         
        for validate_percentile in given_percentile :   
            # print('this is valid 2') 
            if not validate_percentile > 100 :                     
                # print('validiitigy check')            
                KNd100_Plist = []
                for pp in range(0,len(given_percentile)) :            
                    # print()
                    type_100 = 'KNn100_Percentile' 
                    
                    type_jargon ='P'
                    sum_score = group['score_'].sum() 
                    # print(f"\t\t THIS ARE SUM SCORE {sum_score} \n")  
                    
                    KNd100_P = (given_percentile[pp] * sum_score / 100 )        
                    KNd100_Plist.append(KNd100_P)
                    
                    selected_(KNd100_P , pp, type_100, KNd100_Plist, type_jargon)   

                break
                # print("invalid to calculate quartile pls input only [1, 2, 3, 4] in this list")                 
            else : 
                print("invalid to calculate quartile pls input only [1 - 100] in this list")



    # if given_percentile == [] : 
    #     print(f" \n\n Percentile are empty \n\n")
    # else : 
    #     KNd100_Plist = []
    #     for pp in range(0,len(given_percentile)) :            
    #         # print()
    #         sum_score = group['score_'].sum()
    #         type_100 = 'KNn100_Percentile'
    #         KNd100_P = ((given_percentile[pp] * sum_score ) /100)        
    #         print(f"this are  \t\t{KNd100_P} ")
    #         print(f"this are  \t\t{type_100} ")
    #         # print(f"this are  \t\t{su} ")
            
            
    #         KNd100_Plist.append(KNd100_P)
    #         fix_bug(KNd100_P , pp , type_100, KNd100_Plist)
    #         # selected_(KNd100_P , pp , type_100, KNd100_Plist )
    #         # print(f"KNd10_D \t: {} \t {KNd10_D}") 
    #     print(f"this are PLIST \t\t{KNd100_Plist}")
# Out:
#   class_  score_  1st  lowerb  cf
# 5  21-25       6   21    20.5   6
# 4  26-30      12   26    25.5  18
# 3  31-35       9   31    30.5  27
# 2  36-40      11   36    35.5  38
# 1  41-45       8   41    40.5  46
# 0  46-50       4   46    45.5  50
# -----------------------------------------------
#
#
#
# QUARTILE CALCULATION
#
#  THE QUARTILE LIST ARE EMPTY
#
#
# -----------------------------------------------
#
#
#
#   DECILE CALCULATION
#
#
#
#
# FINDING THE D1
#
# from group data of :
#  	['46-50', '41-45', '36-40', '31-35', '26-30', '21-25']
#
# from score dataset of :
#  	[4, 8, 11, 9, 12, 6]
#
# KNn10_Decile 0  		5.0
# lower selected 		: 	20.5
# cf_before 		: 	6
# score selected (FQK) 	: 	6
#
#
#
#
# FINDING THE D3
#
# from group data of :
#  	['46-50', '41-45', '36-40', '31-35', '26-30', '21-25']
#
# from score dataset of :
#  	[4, 8, 11, 9, 12, 6]
#
# KNn10_Decile 1  		15.0
# lower selected 		: 	25.5
# cf_before 		: 	6
# score selected (FQK) 	: 	12
# ...

# %%
#  MEASURE OF POSITION in GROUP DATA v2.0

## List attempt condition
## List attempt condition 


a = r'Lb + \left( \frac {\left(\frac{KN}{4||10||100}\right) - CF_{b}}{F_{qk}}\right)i'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.2,0.4 ,'$%s$' %a,size=50,color="green") 
plt.show()

given = [4 , 8, 11 , 9, 12, 6]
## accept argument with longer list or more ! 
## accept argument with longer list or more ! 
given_quartile = [1,3]
given_decile = [19]
given_percentile = []

def match(grop) : 
    grop[['1st', '2nd']] = grop['class_'].str.split('-', expand=True)  
    grop[['1st', '2nd']] = grop[['1st', '2nd']].astype(int)
    grop.drop('2nd' , axis=1 , inplace=True) 
    grop['lowerb'] =  grop['1st'] - 0.5 
    
    # grop['cumfreq'] = grop.groupby('score_')['score_'].transform('size').cumsum()
    grop.sort_values(by='1st', ascending=True, inplace=True)
    grop['cf']= grop['score_'].cumsum() 

    return grop
    # display(grop)
    
# print("\n\n\n\n\n\n\n\n\n\n\n\n\n") 

def main_calcu(KNd_m , cf_before_m , score_selected_m , interval_m , lowerb_selected_m ) :         
    inner = (KNd_m - cf_before_m) / score_selected_m
    results =  lowerb_selected_m + ( inner * interval_m )             
    return results
    # print(results)
    # return results

def selected_(KNd4, q, KN_type, KN_list, jargon):
    print("\n\n\n") 
    # print("----------------------------------------")   
    # print(f"\n Q{ }")
    # print(f"\n This are from functin {KN_type} : {KNd4}")
    if jargon == 'Q': 
        print(f"FINDING THE Q{ given_quartile[q]} \n")
        
    if jargon == 'D' :
        print(f"FINDING THE D{ given_decile[q]} \n")

    if jargon == 'P': 
        print(f"FINDING THE P{ given_percentile[q]} \n")

    print(f"from group data of : \n \t{clasS} \n")
    print(f"with score dataset of : \n \t{given} \n")
    # if jargon == ''
    
    # print()
    for x in range(group_size -1, -1, -1) :
        group_cf = group['cf'][x]
        # print(f" group_cf \t: \t{group_cf} ") 
        # print("------------------------------")
        if group_cf >=  KNd4: 
            # print("\t\t\t should be stop ! ")                 

            
            print(f"{KN_type} [{q}] \t\t{KNd4}")
            lowerb_selected = group['lowerb'][x]            
            print(f"lower selected(LB) \t \t{lowerb_selected}")
            if KNd4 < group['cf'].min():
                cf_before = group['cf'][x]
            else : 
                cf_before = group['cf'][x+1]                
                
            print(f"cf_before (CFb)\t\t: \t{cf_before}")
            score_selected = group['score_'][x]
            print(f"score selected (FQK) \t: \t{score_selected}")            
            
            interval = group['1st'][0] - group['1st'][1]
            print(f"interval(i) \t\t: \t{interval}")

            # print(4-2)
            
            # def main_calcu(KNd_m , cf_before_m , score_selected_m , interval_m , lowerb_selected_m ) :         
            #     inner = (KNd_m - cf_before_m) / score_selected 
            #     result =  lowerb_selected_m + ( inner * interval_m ) 
            #     return result
                
            main_c = main_calcu(KNd4, cf_before , score_selected , interval , lowerb_selected )

            if jargon == 'Q': 
                print(f"Answer of Q{given_quartile[q]} \t= {main_c}  \n")
                
            if jargon == 'D' :
                # print(f"FINDING THE D{ given_decile[q]} \n")
                print(f"Answer of D{given_decile[q]} \t= {main_c}  \n")
        
            if jargon == 'P': 
                # print(f"FINDING THE P{ given_percentile[q]} \n")
                print(f"Answer of P{ given_percentile[q]} \t= {main_c}  \n")
            
            # print(f"{gin}  \t\t{main_c}")
            
            
            
                
            break     
            
        # else :             
            # print(" \n\n elseeeeeee ")
            # print(f"{group_cf} are less than {KN_list[q]}") 

        
if len(clasS) == len(given) :
    group = pd.DataFrame({
        'class_': clasS  , 
        'score_' : given          
    }) 
    
    match(group) 
    display(group)    
    group_size = group.index.size
    
    print("----------------------------------------------- \n\n\n")
    
    right_aligned = 'QUARTILE CALCULATION'.rjust(20) 
    print(right_aligned)

    
    if given_quartile == [] :
        print(f"\n THE QUARTILE LIST ARE EMPTY  \n\n") 
    else :      
        
        for validate_quartile in given_quartile :        
            ## validate if given quartile are okay             
            if not validate_quartile > 4 : 
                KNd4_Qlist = [] 
                for q in range(0,len(given_quartile) ):
                    type_4 = 'KNd4_Quartile'
                    sum_score = group['score_'].sum()
                    KNd4_Q = ((given_quartile[q] * sum_score/4))               
                    # print(f" KNd4_Q {given_quartile[q]} \t: \t{KNd4_Q}") 
                    KNd4_Qlist.append(KNd4_Q)   
                    jargon = 'Q'
                    selected_(KNd4_Q , q, type_4, KNd4_Qlist, jargon)     
            
                    
                break 
            else : 
                print("invalid to calculate quartile pls input only [1, 2, 3, 4] in this list")
        


    print("----------------------------------------------- \n\n\n")    
    right_aligned = 'DECILE CALCULATION'.rjust(20) 
    print(right_aligned)
    
    if given_decile == [] : 
        print(f" \n THE GIVEN DECILE ARE EMPTY \n\n")
    else :          
        # print('this is valid decile') 
        
        for validate_decile in given_decile :   
            # print('this is valid 2') 
            if validate_decile < 10 :                     
                # print('validiitigy check')            
                KNd10_Dlist = []
                for dd in range(0,len(given_decile)) :            
                    # print()
                    type_10 = 'KNn10_Decile' 
                    sum_score = group['score_'].sum() 
                    KNd10_D = ((given_decile[dd] * sum_score) /10)        
                    KNd10_Dlist.append(KNd10_D)
                    jargon = 'D'
                    
                    selected_(KNd10_D , dd, type_10, KNd10_Dlist , jargon)
                    # print(f"KNd10_D \t: {} \t {KNd10_D}")         
                break
                # print("invalid to calculate quartile pls input only [1, 2, 3, 4] in this list")                 
            else : 
                print("invalid to calculate quartile pls input only [1-10] in this list")
                # break 
    
    print("----------------------------------------------- \n\n\n")
    right_aligned = 'PERCENTILE CALCUTION'.rjust(20) 
    print(f"{right_aligned} \n\n")
    

    if given_percentile == [] : 
        print(f" \n\n THE GIVEN PERCENTILE ARE EMPTY \n\n")
    else :          
        # print('this is valid decile')         
        for validate_percentile in given_percentile :   
            # print('this is valid 2') 
            if not validate_percentile > 100 :                     
                # print('validiitigy check')            
                KNd100_Plist = []
                for pp in range(0,len(given_percentile)) :            
                    # print()
                    type_100 = 'KNn100_Percentile' 
                    
                    type_jargon ='P'
                    sum_score = group['score_'].sum() 
                    # print(f"\t\t THIS ARE SUM SCORE {sum_score} \n")  
                    
                    KNd100_P = (given_percentile[pp] * sum_score / 100 )        
                    KNd100_Plist.append(KNd100_P)
                    
                    selected_(KNd100_P , pp, type_100, KNd100_Plist, type_jargon)   

                break
                # print("invalid to calculate quartile pls input only [1, 2, 3, 4] in this list")                 
            else : 
                print("invalid to calculate quartile pls input only [1 - 100] in this list")



    # if given_percentile == [] : 
    #     print(f" \n\n Percentile are empty \n\n")
    # else : 
    #     KNd100_Plist = []
    #     for pp in range(0,len(given_percentile)) :            
    #         # print()
    #         sum_score = group['score_'].sum()
    #         type_100 = 'KNn100_Percentile'
    #         KNd100_P = ((given_percentile[pp] * sum_score ) /100)        
    #         print(f"this are  \t\t{KNd100_P} ")
    #         print(f"this are  \t\t{type_100} ")
    #         # print(f"this are  \t\t{su} ")
            
            
    #         KNd100_Plist.append(KNd100_P)
    #         fix_bug(KNd100_P , pp , type_100, KNd100_Plist)
    #         # selected_(KNd100_P , pp , type_100, KNd100_Plist )
    #         # print(f"KNd10_D \t: {} \t {KNd10_D}") 
    #     print(f"this are PLIST \t\t{KNd100_Plist}")
# Out:
#   class_  score_  1st  lowerb  cf
# 5  21-25       6   21    20.5   6
# 4  26-30      12   26    25.5  18
# 3  31-35       9   31    30.5  27
# 2  36-40      11   36    35.5  38
# 1  41-45       8   41    40.5  46
# 0  46-50       4   46    45.5  50
# -----------------------------------------------
#
#
#
# QUARTILE CALCULATION
#
#
#
#
# FINDING THE Q1
#
# from group data of :
#  	['46-50', '41-45', '36-40', '31-35', '26-30', '21-25']
#
# with score dataset of :
#  	[4, 8, 11, 9, 12, 6]
#
# KNd4_Quartile [0] 		12.5
# lower selected(LB) 	 	25.5
# cf_before (CFb)		: 	6
# score selected (FQK) 	: 	12
# interval(i) 		: 	5
# Answer of Q1 	= 28.208333333333332
#
#
#
#
#
# FINDING THE Q3
#
# from group data of :
#  	['46-50', '41-45', '36-40', '31-35', '26-30', '21-25']
#
# with score dataset of :
#  	[4, 8, 11, 9, 12, 6]
#
# KNd4_Quartile [1] 		37.5
# lower selected(LB) 	 	35.5
# cf_before (CFb)		: 	27
# score selected (FQK) 	: 	11
# interval(i) 		: 	5
# Answer of Q3 	= 40.27272727272727
#
# ...

# %%
import matplotlib.pyplot as plt

# a = 'shit'
# b = 'ness'
a = '\\frac{heyo}{b}'  #notice escaped slash
plt.plot()
plt.text(0.5, 0.5,'$%s$'%a)
plt.show()

# %%
immport

a = r'Lb + \left( \frac {\left(\frac{KN}{4}\right) - CF_{b}}{F_{qk}}\right)i'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
pl = plt.text(0.2,0.4 ,'$%s$' %a,size=50,color="green") 
# plt.clf()

# a = r'\frac{KN}{4}'
# # a = r' \left(\frac{KN}{4}\right) - CF{b}'
# ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
# ax.set_xticks([])
# ax.set_yticks([])
# ax.axis('off')
# pepsi = plt.text(0.4, 1,'$%s$' %a,size=50,color="green")


# print(f"\n\n\n\n")
# pepsi

# %%
# display(group)
# 5.0 < group['cf'].min()
# print(group['cf'][5]) 
print(group['1st'][0] - group['1st'][1])
print(group['1st'][0] - group['1st'][1])
# Out:
# 5
# 5
