# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
df_sheet1 = pd.read_excel('sampol.xlsx' , sheet_name='Sheet1')
df_sheet2 = pd.read_excel('sampol.xlsx' , sheet_name='Sheet2')
df_sheet1 = df_sheet1.rename(columns=lambda x: x.replace(' ', '_'))
df_sheet2 = df_sheet2.rename(columns=lambda x: x.replace(' ', '_'))
df_sheet1['DATE'] = pd.to_datetime(df_sheet1['DATE'])
df_sheet2['DATE'] = pd.to_datetime(df_sheet2['DATE'])

df_sheet1
# Out:
#     LOAN_ID       DATE      DEPTOR  AMOUNT
# 0        11 2003-12-03      Bickle      53
# 1        12 2003-02-04   Salvatore      10
# 2        13 2003-04-18    Hardaker      68
# 3        14 2003-01-22     Lockery      99
# 4        15 2003-01-15   Langstaff      70
# 5        16 2003-03-25      Leport       3
# 6         6 2003-05-25  Dzenisenka      20
# 7         6 2003-05-23  Dzenisenka      20
# 8         7 2003-07-20   McQuarrie      10
# 9         8 2003-08-19      Bidgod      63
# 10        9 2003-05-26     Dengate      24
# 11       10 2003-02-03    Dummigan       2

# %%
df_sheet1['row_num'] = df_sheet1.groupby('LOAN_ID') .cumcount() + 1
df_sheet2['row_num'] = df_sheet2.groupby('LOAN_ID') .cumcount() + 1

df_sheet1
# Out:
#     LOAN_ID       DATE      DEPTOR  AMOUNT  row_num
# 0        11 2003-12-03      Bickle      53        1
# 1        12 2003-02-04   Salvatore      10        1
# 2        13 2003-04-18    Hardaker      68        1
# 3        14 2003-01-22     Lockery      99        1
# 4        15 2003-01-15   Langstaff      70        1
# 5        16 2003-03-25      Leport       3        1
# 6         6 2003-05-25  Dzenisenka      20        1
# 7         6 2003-05-23  Dzenisenka      20        2
# 8         7 2003-07-20   McQuarrie      10        1
# 9         8 2003-08-19      Bidgod      63        1
# 10        9 2003-05-26     Dengate      24        1
# 11       10 2003-02-03    Dummigan       2        1

# %%
merg_sheet = pd.merge(df_sheet1, df_sheet2 , on=['LOAN_ID' , 'row_num'] , how='inner') 
merg_sheet
# Out:
#    LOAN_ID     DATE_x    DEPTOR_x  AMOUNT_x  row_num     DATE_y    DEPTOR_y  \
# 0        6 2003-05-25  Dzenisenka        20        1 2003-05-25  Dzenisenka
# 1        7 2003-07-20   McQuarrie        10        1 2003-07-19   McQuarrie
# 2        8 2003-08-19      Bidgod        63        1 2003-08-19      Bidgod
# 3        9 2003-05-26     Dengate        24        1 2003-05-27     Dengate
# 4       10 2003-02-03    Dummigan         2        1 2003-02-03    Dummigan
#
#    AMOUNT_y
# 0        20
# 1         9
# 2        63
# 3        18
# 4         2

# %%
nice =  merg_sheet['LOAN_ID'].tolist()
nice
must_merge = df_sheet2.query("LOAN_ID != @nice") 
must_merge

combined_df = pd.concat([df_sheet1, must_merge], ignore_index=True)
combined_df
# Out:
#     LOAN_ID       DATE        DEPTOR  AMOUNT  row_num
# 0        11 2003-12-03        Bickle      53        1
# 1        12 2003-02-04     Salvatore      10        1
# 2        13 2003-04-18      Hardaker      68        1
# 3        14 2003-01-22       Lockery      99        1
# 4        15 2003-01-15     Langstaff      70        1
# 5        16 2003-03-25        Leport       3        1
# 6         6 2003-05-25    Dzenisenka      20        1
# 7         6 2003-05-23    Dzenisenka      20        2
# 8         7 2003-07-20     McQuarrie      10        1
# 9         8 2003-08-19        Bidgod      63        1
# 10        9 2003-05-26       Dengate      24        1
# 11       10 2003-02-03      Dummigan       2        1
# 12        1 2003-06-24  Milton-White      56        1
# 13        2 2003-06-20      Medcalfe      82        1
# 14        3 2003-06-15         Peggs      16        1
# 15        4 2003-08-18      Rollason      15        1
# 16        5 2003-07-27    De Andreis      92        1

# %%
# merg_sheet['']

# merg_sheet['']



# df_sheet1.query('"LOAN ID" == 12')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\enerv\anaconda3\Lib\site-packages\pandas\core\computation\ops.py:268, in _in(x, y)
#     267 try:
# --> 268     return x.isin(y)
#     269 except AttributeError:
#
# AttributeError: 'list' object has no attribute 'isin'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 9
#       1 merg_sheet = pd.merge(df_sheet1, df_sheet2 , on=['LOAN ID' , 'row_num'] , how='inner')
#       3 # merg_sheet['']
#       4
#       5 # merg_sheet['']
# ----> 9 df_sheet1.query('"LOAN ID" == 12')
#
# File c:\Users\enerv\anaconda3\Lib\site-packages\pandas\core\frame.py:4599, in DataFrame.query(self, expr, inplace, **kwargs)
#    4597 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4598 kwargs["target"] = None
# -> 4599 res = self.eval(expr, **kwargs)
#    4601 try:
#    4602     result = self.loc[res]
#
# File c:\Users\enerv\anaconda3\Lib\site-packages\pandas\core\frame.py:4725, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4722     kwargs["target"] = self
#    4723 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4725 return _eval(expr, inplace=inplace, **kwargs)
#
# File c:\Users\enerv\anaconda3\Lib\site-packages\pandas\core\computation\eval.py:336, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     327 # get our (possibly passed-in) scope
#     328 env = ensure_scope(
#     329     level + 1,
#     330     global_dict=global_dict,
#    (...)
#     333     target=target,
#     334 )
# --> 336 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     338 if engine == "numexpr" and (
#     339     is_extension_array_dtype(parsed_expr.terms.return_type)
#     340     or getattr(parsed_expr.terms, "operand_types", None) is not None
#    (...)
#     344     )
#     345 ):
#     346     warnings.warn(
#     347         "Engine has switched to 'python' because numexpr does not support "
#     348         "extension array dtypes. Please set your engine to python manually.",
#     349         RuntimeWarning,
#     350         stacklevel=find_stack_level(),
#     351     )
#
# File c:\Users\enerv\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:808, in Expr.__init__(self, expr, engine, parser, env, level)
#     806 self.parser = parser
#     807 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 808 self.terms = self.parse()
#
# File c:\Users\enerv\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:827, in Expr.parse(self)
#     823 def parse(self):
#     824     """
#     825     Parse an expression.
#     826     """
# --> 827     return self._visitor.visit(self.expr)
#
# File c:\Users\enerv\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File c:\Users\enerv\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:417, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     415     raise SyntaxError("only a single expression is allowed")
#     416 expr = node.body[0]
# --> 417 return self.visit(expr, **kwargs)
#
# File c:\Users\enerv\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File c:\Users\enerv\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:420, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     419 def visit_Expr(self, node, **kwargs):
# --> 420     return self.visit(node.value, **kwargs)
#
# File c:\Users\enerv\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File c:\Users\enerv\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:718, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     716     op = self.translate_In(ops[0])
#     717     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 718     return self.visit(binop)
#     720 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     721 left = node.left
#
# File c:\Users\enerv\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File c:\Users\enerv\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:533, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     531 op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     532 left, right = self._maybe_downcast_constants(left, right)
# --> 533 return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File c:\Users\enerv\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:519, in BaseExprVisitor._maybe_evaluate_binop(self, op, op_class, lhs, rhs, eval_in_python, maybe_eval_in_python)
#     515     return self._maybe_eval(res, self.binary_ops)
#     517 if res.op in eval_in_python:
#     518     # "in"/"not in" ops are always evaluated in python
# --> 519     return self._maybe_eval(res, eval_in_python)
#     520 elif self.engine != "pytables":
#     521     if (
#     522         getattr(lhs, "return_type", None) == object
#     523         or getattr(rhs, "return_type", None) == object
#     524     ):
#     525         # evaluate "==" and "!=" in python if either of our operands
#     526         # has an object return type
#
# File c:\Users\enerv\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:487, in BaseExprVisitor._maybe_eval(self, binop, eval_in_python)
#     480 def _maybe_eval(self, binop, eval_in_python):
#     481     # eval `in` and `not in` (for now) in "partial" python space
#     482     # things that can be evaluated in "eval" space will be turned into
#    (...)
#     485     # in that case a + 2 * b will be evaluated using numexpr, and the "in"
#     486     # call will be evaluated using isin (in python space)
# --> 487     return binop.evaluate(
#     488         self.env, self.engine, self.parser, self.term_type, eval_in_python
#     489     )
#
# File c:\Users\enerv\anaconda3\Lib\site-packages\pandas\core\computation\ops.py:452, in BinOp.evaluate(self, env, engine, parser, term_type, eval_in_python)
#     450 # base cases
#     451 if self.op in eval_in_python:
# --> 452     res = self.func(left.value, right.value)
#     453 else:
#     454     from pandas.core.computation.eval import eval
#
# File c:\Users\enerv\anaconda3\Lib\site-packages\pandas\core\computation\ops.py:275, in _in(x, y)
#     273     except AttributeError:
#     274         pass
# --> 275 return x in y
#
# TypeError: argument of type 'int' is not iterable
