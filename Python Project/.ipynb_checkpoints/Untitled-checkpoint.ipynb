# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
df = pd.DataFrame(
    {'Type': ["A" , "B" , "C" , "D" , "E" , "F" , "G"]  ,  
     'Valuez' : [25, 24 , 20, 14, 13 ,21 , 18]   
    }
)

# %%
df['mean'] = df['Valuez'].mean()
df 
# ['Valuez']
# df['Valuez'].mean()
# Out:
#   Type  Valuez       mean
# 0    A      25  19.285714
# 1    B      24  19.285714
# 2    C      20  19.285714
# 3    D      14  19.285714
# 4    E      13  19.285714
# 5    F      21  19.285714
# 6    G      18  19.285714

# %%
df['Valuez-mean'] = df['Valuez'] - df['mean']

# %%
def assign_green(row): 
    if row['Valuez-mean'] < 0 :
        return row['Valuez-mean']
    else :
        return ""

def assign_red(row): 
    if row['Valuez-mean'] > 0 :
        return row['Valuez-mean']
    else :
        return ""

df['green'] = df.apply(assign_green , axis=1)
df['red'] = df.apply(assign_red, axis=1)
df


# df.type
# print(df['green'].dtypes)
# Out:
#   Type  Valuez       mean  Valuez-mean     green       red
# 0    A      25  19.285714     5.714286            5.714286
# 1    B      24  19.285714     4.714286            4.714286
# 2    C      20  19.285714     0.714286            0.714286
# 3    D      14  19.285714    -5.285714 -5.285714
# 4    E      13  19.285714    -6.285714 -6.285714
# 5    F      21  19.285714     1.714286            1.714286
# 6    G      18  19.285714    -1.285714 -1.285714

# %%
plt.plot(df['Type'] , df['Valuez'] , color='grey' , label='actual_value')
plt.plot(df['Type'] ,  df['mean'] , color='r' , alpha=0.3, linestyle='--' , label='mean')

plt.legend()

# %%
# Sample data with specific x-values
x = [19, 20, 21, 22, 23, 24]
y1 = [0, 1, 4, 9, 16, 25]
y2 = [0, 1, 2, 3, 4, 5]

# Create the plot
plt.plot(x, y1, marker='o', linestyle='-', color='b', alpha=0.7, label='y = x^2')
plt.plot(x, y2, marker='s', linestyle='--', color='r', alpha=0.7, label='y = x')

# Add title and labels
plt.title('Line Plot with Custom X-axis Values and Labels')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
plt.style.use('_mpl-gallery')

# make data
np.random.seed(1)
x = np.linspace(0, 8, 16)
y1 = 3 + 4*x/8 + np.random.uniform(0.0, 0.5, len(x))
y2 = 1 + 2*x/8 + np.random.uniform(0.0, 0.5, len(x))

# plot
fig, ax = plt.subplots()

ax.fill_between(x, y1, y2, alpha=.5, linewidth=0)
# ax.plot(x, (y1 + y2)/2, linewidth=2)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
plt.figure(figsize=(9, 6))  # Optional: Set the size of the figure
plt.subplot(1, 3, 3)  # Create the first subplot
plt.plot([1, 2, 3], [4, 5, 6] , marker='o')  # Plot in the first subplot
plt.title('Subplot 1') 
plt.subplot(1, 3,  3) # Create the second subplot 
plt.title('Subplot 2')

plt.subplot(1, 3, 3)  # Create the second subplot 
plt.title('Subplot 3')
plt.tight_layout()  # Optional: Adjust subplot parameters to give specified padding
plt.show()

# %%
# plt.figure(figsize=(10, 6))

fig , (ax1, ax2 , ax3) = plt.subplots(1, 3 ,  figsize=(12, 6)) 
ax1.plot(df['Type'] , df['Valuez'] , color='grey' , label='actual_value')
ax2.plot(df['Type'] , df['Valuez'] , color='grey' , label='actual_value')
# ax1.set_facecolor('red')

ax2.bar(df['Type'] , df['Valuez']   )
# Out:
# <BarContainer object of 7 artists>

# %%
# Out:
# [ 1  4  7 10]
