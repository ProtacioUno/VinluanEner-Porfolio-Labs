# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt

# %%
# I CREATED random DATASET
ungrok = []
for x in range(600000) :
    randonk_int = np.random.randint(1, 50)
    ungrok.append(randonk_int) 
# ungrok

# %%
 
ungroup = pd.DataFrame(
    {'X': ungrok }
)

ungroup.head()
# giv_example[]
# Out:
#     X
# 0  37
# 1   7
# 2   8
# 3  10
# 4   9

# %% [markdown]
# # UNGROUP STANDARD DEVIATION

# %%
# Calculate its UNGROUP STANDARD DEVIATION FOR POPULATION
# Calculate its UNGROUP STANDARD DEVIATION FOR POPULATION
# Calculate its UNGROUP STANDARD DEVIATION FOR POPULATION

    # This mini project contains manual calculations for standard deviation, 
    # which I've learned in Statistics, and applies them in Python analysis.
    


ungroup['mean_x'] = ungroup['X'].mean() 

ungroup['X-x'] = ungroup['X'] - ungroup['X'].mean()

ungroup['(X-x)^2'] = ungroup['X-x'].pow(2)
# age_sums = age_sum.item() 
ungroup['sum(X-x^2)'] = ungroup['(X-x)^2'].sum()


def show_group () : 
    mean_x = ungroup['X'].mean() 
    print(f"mean of X == {mean_x}")
    sum_pow2 = ungroup['(X-x)^2'].sum()
    print(f"sum of (X-x)^2 == {sum_pow2}")
    N = len(ungroup['X']) 
    print(f"Sample size of {N}")
    under = sum_pow2 / N
    print(f"Under : {under}")

    import math

    print(f" Standard Deviation == {math.sqrt(under)}" )

# ungroup = ungroup.reindex(columns=['X', 'mean_x', 'X-x', '(X-x)^2', ])

show_group()
ungroup
# Out:
# mean of X == 25.017641666666666
# sum of (X-x)^2 == 120099120.26295833
# Sample size of 600000
# Under : 200.1652004382639
#  Standard Deviation == 14.147975135625023
#          X     mean_x        X-x     (X-x)^2    sum(X-x^2)
# 0       37  25.017642  11.982358  143.576911  1.200991e+08
# 1        7  25.017642 -18.017642  324.635411  1.200991e+08
# 2        8  25.017642 -17.017642  289.600128  1.200991e+08
# 3       10  25.017642 -15.017642  225.529561  1.200991e+08
# 4        9  25.017642 -16.017642  256.564845  1.200991e+08
# ...     ..        ...        ...         ...           ...
# 599995  40  25.017642  14.982358  224.471061  1.200991e+08
# 599996  35  25.017642   9.982358   99.647478  1.200991e+08
# 599997  33  25.017642   7.982358   63.718045  1.200991e+08
# 599998   7  25.017642 -18.017642  324.635411  1.200991e+08
# 599999  33  25.017642   7.982358   63.718045  1.200991e+08
#
# [600000 rows x 5 columns]

# %%
ungroup['mean_x'] = ungroup['X'].mean() 

ungroup['X-x'] = ungroup['X'] - ungroup['X'].mean()

ungroup['(X-x)^2'] = ungroup['X-x'].pow(2)
# age_sums = age_sum.item() 
ungroup['sum(X-x^2)'] = ungroup['(X-x)^2'].sum()


def show_group () : 
    mean_x = ungroup['X'].mean() 
    print(f"mean of X == {mean_x}")
    sum_pow2 = ungroup['(X-x)^2'].sum()
    print(f"sum of (X-x)^2 == {sum_pow2}") 
    N = len(ungroup['X']) 
    print(f"Sample size of {N}")
    under = sum_pow2 / N
    print(f"Under : {under}")
    import math
    print(f" Standard Deviation == {math.sqrt(under)}" )

show_group()

group
# ungroup = ungroup.reindex(columns=['X', 'mean_x', 'X-x', '(X-x)^2', ])

# %% [markdown]
# # GROUP STANDARD DEVIATION

# %%
## GROUP STANDARD DEVIATION 
## GROUP STANDARD DEVIATION 


grp = ['50-59' , '60-69' ,  '70-79', '80-89', '90-100']
X = [3 , 5, 9, 12, 8]

group =pd.DataFrame({
    'class_' : grp , 
    'X' : X 
})

print(group)

plt.figure(facecolor='black') 
a = r'\bar{x}=\frac{\sum_{}^{}f*m}{f}'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.2,0.4 ,'$%s$' %a,size=50 , color='white') 
plt.show()
# Out:
#    class_   X
# 0   50-59   3
# 1   60-69   5
# 2   70-79   9
# 3   80-89  12
# 4  90-100   8

# %%
group[['1st', '2nd']]= group['class_'].str.split('-', expand=True)
group[['1st', '2nd']]= group[['1st' , '2nd']].astype(int)
group['midpoint'] = (group['1st'] + group['2nd']) / 2 
group['f*midp'] = group['X'] * group['midpoint'] 
group['Mean'] = group['f*midp'].sum() / group['X'].sum()
group['m-Mean'] = group['midpoint'] - group['Mean']
group['m-Mean^2'] = group['m-Mean'].pow(2)
group['sum(m-Mean^2)'] = group['m-Mean^2'].sum()
group['N-1'] = group['X'].sum() - 1 
group["std_deviation"] = group['sum(m-Mean^2)'] / group['N-1']
print(group.dtypes)
group
# print()q
# Out:
# class_            object
# X                  int64
# 1st                int32
# 2nd                int32
# midpoint         float64
# f*midp           float64
# Mean             float64
# m-Mean           float64
# m-Mean^2         float64
# sum(m-Mean^2)    float64
# N-1                int64
# std_deviation    float64
# dtype: object
#    class_   X  1st  2nd  midpoint  f*midp       Mean     m-Mean    m-Mean^2  \
# 0   50-59   3   50   59      54.5   163.5  79.202703 -24.702703  610.223521
# 1   60-69   5   60   69      64.5   322.5  79.202703 -14.702703  216.169467
# 2   70-79   9   70   79      74.5   670.5  79.202703  -4.702703   22.115413
# 3   80-89  12   80   89      84.5  1014.0  79.202703   5.297297   28.061359
# 4  90-100   8   90  100      95.0   760.0  79.202703  15.797297  249.554602
#
#    sum(m-Mean^2)  N-1  std_deviation
# 0    1126.124361   36      31.281232
# 1    1126.124361   36      31.281232
# 2    1126.124361   36      31.281232
# 3    1126.124361   36      31.281232
# 4    1126.124361   36      31.281232

# %%
def latex_func(latex):
    plt.figure(facecolor='black')     
    ax = plt.axes([0,0,0.3,0.3]) #lefte,bottom,width,height
    ax.set_xticks([])
    ax.set_yticks([])
    ax.axis('off')
    plt.text(0.2,0.4 ,'$%s$' %a_subs ,size=50,color="white") 
    plt.show() 


def group_functin (groop) : 
    groop[['1st', '2nd']]= groop['class_'].str.split('-', expand=True)
    groop[['1st', '2nd']]= groop[['1st' , '2nd']].astype(int)
    groop['midpoint'] = (groop['1st'] + groop['2nd']) / 2 
    groop['f*midp'] = groop['X'] * groop['midpoint'] 
    groop['Mean'] = groop['f*midp'].sum() / groop['X'].sum()
    groop['m-Mean'] = groop['midpoint'] - groop['Mean']
    groop['m-Mean^2'] = groop['m-Mean'].pow(2)
    groop['f(m-Mean)^2)'] =  groop['X'] * groop['m-Mean^2']  
    groop['sum(f(m-Mean)^2)'] =   groop['f(m-Mean)^2)'].sum()
    # groop['sum(m-Mean^2)'] = groop['m-Mean^2'].sum()
    # groop['']
    sum_X = groop['X'].sum()
    sum_fxM = groop['f*midp'].sum()
    # groop['sum(f(m-Mean)^2)'] 
    # sum_ = groop['f(m-Mean)^2)'].sum()
    # sum_

    print("sum_x \t\t\t" , sum_X)
    print("sum_fxM \t\t" , sum_fxM)
    print('sum_(f(m-Mean)^2) \t' ,  groop['sum(f(m-Mean)^2)'][0]) 
    # print("sum_x" , )sum_f(m_Mean)pow_2

    
    # groop['N-1'] = groop['X'].sum() - 1 
    # groop["std_deviation"] = groop['sum(m-Mean^2)'] / groop['N-1']
    # return groop

    
    plt.figure(facecolor='black')     
    a = r's=\sqrt{\frac{\sum_{}^{}f(m*\bar{x})^{2}}{n-1}}'
    ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
    ax.set_xticks([])
    ax.set_yticks([])
    ax.axis('off')
    plt.text(0.2,0.4 ,'$%s$' %a,size=50 , color='white') 
    plt.show() 

    upper = group['sum(f(m-Mean)^2)'] 



    # n = 1444
    a_subs = r'\sqrt{\frac{ %d }{ %d - 1}}' % (upper[0], sum_X) 
    
    latex_func(a_subs)
     


  
    
group_functin(group)

group
# Out:
# sum_x 			 37
# sum_fxM 		 2930.5
# sum_(f(m-Mean)^2) 	 5443.72972972973
#    class_   X  1st  2nd  midpoint  f*midp       Mean     m-Mean    m-Mean^2  \
# 0   50-59   3   50   59      54.5   163.5  79.202703 -24.702703  610.223521
# 1   60-69   5   60   69      64.5   322.5  79.202703 -14.702703  216.169467
# 2   70-79   9   70   79      74.5   670.5  79.202703  -4.702703   22.115413
# 3   80-89  12   80   89      84.5  1014.0  79.202703   5.297297   28.061359
# 4  90-100   8   90  100      95.0   760.0  79.202703  15.797297  249.554602
#
#    f(m-Mean)^2)  sum(f(m-Mean)^2))  sum(f(m-Mean)^2)
# 0   1830.670562         5443.72973        5443.72973
# 1   1080.847334         5443.72973        5443.72973
# 2    199.038714         5443.72973        5443.72973
# 3    336.736304         5443.72973        5443.72973
# 4   1996.436815         5443.72973        5443.72973

# %%
# a_subs = r'\frac{ %d (%d) -  %d (%d) }   {\sqrt{[ %d (%d) -(%d)^{2} ]   [%d (%d) -(%d)^{2}] }} '  % (n , xy,  x , y , n, xpow2, x , n , ypow2 , y)




def latex_func(latex):
    plt.figure(facecolor='black')     
    ax = plt.axes([0,0,0.3,0.3]) #lefte,bottom,width,height
    ax.set_xticks([])
    ax.set_yticks([])
    ax.axis('off')
    plt.text(0.2,0.4 ,'$%s$' %a_subs ,size=50,color="white") 
    plt.show() 


upper = group['sum(f(m-Mean)^2)'] 

# new_upper = upper.astype(int)
# print(type(new_upper))
# print(type(new_upper))

# n = 1444
a_subs = r'\sqrt{\frac{ %d }{ %d - 1}}' % (upper[0], sum_X) 

latex_func(a_subs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[285], line 23
#      16 upper = group['sum(f(m-Mean)^2)']
#      18 # new_upper = upper.astype(int)
#      19 # print(type(new_upper))
#      20 # print(type(new_upper))
#      21
#      22 # n = 1444
# ---> 23 a_subs = r'\sqrt{\frac{ %d }{ %d - 1}}' % (upper[0], sum_X)
#      25 latex_func(a_subs)
#
# NameError: name 'sum_X' is not defined

# %%
series = pd.Series([1.1, 2.2, 3.3, 4.4])

# Cast the series to integer type
series_as_int = series.astype(int)

print(series_as_int)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int32

# %%
# type(group['sum(f(m-Mean)^2)'][0]
# Out:
# numpy.float64
