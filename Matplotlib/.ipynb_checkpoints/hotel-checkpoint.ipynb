# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_book = pd.read_csv('dateset/hotel_bookings.csv', header=0)  
df_book.head()
# df_hr.dtypes
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
#
# [5 rows x 32 columns]

# %%
df_book.groupby('arrival_date_month')['hotel'].count()
# Out:
# arrival_date_month
# April        11089
# August       13877
# December      6780
# February      8068
# January       5929
# July         12661
# June         10939
# March         9794
# May          11791
# November      6794
# October      11160
# September    10508
# Name: hotel, dtype: int64

# %%
# df_book.columns
plt.style.use('fivethirtyeight')


montly = df_book.pivot_table(values="hotel" , index='arrival_date_month' , aggfunc='count' )

df_motly = pd.DataFrame(montly)
df_motly
# Out:
#                     hotel
# arrival_date_month
# April               11089
# August              13877
# December             6780
# February             8068
# January              5929
# July                12661
# June                10939
# March                9794
# May                 11791
# November             6794
# October             11160
# September           10508

# %%
plt.style.use('ggplot')
plt.bar(df_motly.index ,  df_motly['hotel'] , width=0.7)
plt.title("Months")
plt.xticks(rotation=45)
plt.subplots_adjust(wspace= 200)
plt.show()
# df_motly.plt(kind='bar' ) 

# df_motly.

# %%
month = ['Feb' , 'Jan' , 'Mar']
def get_month(month): 
    month_order = ['Jan' , 'Feb', 'Mar']

    # print(month_order.index(month))
    print(month_order.index(month))

get_month(month)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 8
#       5     # print(month_order.index(month))
#       6     print(month_order.index(month))
# ----> 8 get_month(month)
#
# Cell In[36], line 6, in get_month(month)
#       3 month_order = ['Jan' , 'Feb', 'Mar']
#       5 # print(month_order.index(month))
# ----> 6 print(month_order.index(month))
#
# ValueError: ['Feb', 'Jan', 'Mar'] is not in list

# %%
months = ['July', 'September', 'January', 'March', 'December', 'April', 'May', 'October', 'August', 'November', 'February', 'June']

# Define a function to extract the month's numerical position
def get_month_index(month):
    month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
    # print( month_order.index(month))
    # returnt())
    

# month 
months.index()
# get_month_index(months)
# Sort the list of months using the custom key function
# sorted_months = sorted(months, key=get_month_index)
# print(sorted_months)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 10
#       6     print( month_order.index(month))
#       9 # month
# ---> 10 months.index()
#
# TypeError: index expected at least 1 argument, got 0
