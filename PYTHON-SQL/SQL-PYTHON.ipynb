# %%
import mysql.connector as MySQLdb 
import pandas as pd

# %%
username = 'Eners'
# password = 'imDev888'
password = "0912"; 
hostname = "127.0.0.1"
# hostname = "conn01"
port = 3306
database_name = 'basee'

# Create an engine to connect to the MySQL database
engine = create_engine(f'mysqldb://{username}:{password}@127.0.0.1:{port}/{database_name}')


# engine = create_engine('mysql://Eners:imDev888@localhost:3306/basee')
# engine = create_engin
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13684\1496519331.py in <module>
#       8
#       9 # Create an engine to connect to the MySQL database
# ---> 10 engine = create_engine(f'mysqldb://{username}:{password}@127.0.0.1:{port}/{database_name}')
#      11
#      12
#
# NameError: name 'create_engine' is not defined

# %% [markdown]
# # Solo mysql.connector
# without mysql.connector

# %%
# import MySQLdb 


import mysql.connector as MySQLdb 
import pandas as pd
# import mysql.

connection = MySQLdb.connect(host='127.0.0.1', user='Eners', passwd='imDev888', db='schema_001')
cursor = connection.cursor()
## query 

cursor.execute('SELECT * FROM income_statement LIMIT 4') 
results = cursor.fetchall() 
df_result = pd.DataFrame(results, columns=income_statement.columns.keys() ) 
# the columns=income_statement.columns.keys() are connectortign to ro frame 
df_result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13684\1783919122.py in <module>
#      12 cursor.execute('SELECT * FROM income_statement LIMIT 4')
#      13 results = cursor.fetchall()
# ---> 14 df_result = pd.DataFrame(results, columns=income_statement.columns.keys() )
#      15 # the columns=income_statement.columns.keys() are connectortign to ro frame
#      16 df_result
#
# NameError: name 'income_statement' is not defined

# %% [markdown]
# ### THIS kind of query only accept if QUERY AND columns.keys are match by column lenght

# %%
def querys(querry) : 
    cursor = connection.cursor()
    cursor.execute(querry) 
    results = cursor.fetchall() 
    df_result = pd.DataFrame(results, columns=income_statement.columns.keys() ) 
    # the columns=income_statement.columns.keys() are connectortign to ro frame 
    display(df_result)
    
querys('SELECT * FROM income_statement LIMIT 4') 

    # THIS kind of query only accept if QUERY AND columns.keys are match by column lenght 
    #

# %% [markdown]
# # CREAT_ENGINE

# %%
from sqlalchemy import create_engine, MetaData, Table, select
## this this sqlalchemy.create_engine but cannow accept create_engine only 

engine = create_engine('mysql+mysqlconnector://Eners:imDev888@127.0.0.1:3306/schema_001', echo=True)
metadata = MetaData() 


income_statement = Table('income_statement' , metadata , autoload=True , autoload_with=engine)

print(repr (metadata.tables['income_statement']) )  

# (n) print(type(MetaData())) 
# print()

# %% [markdown]
# ### using sqr loop

# %%
from sqlalchemy import create_engine, MetaData, Table, select
## this this sqlalchemy.create_engine but cannow accept create_engine only 

engine = create_engine('mysql+mysqlconnector://Eners:imDev888@127.0.0.1:3306/schema_001', echo=True)
metadata = MetaData() 

income_statement = Table('income_statement' , metadata , autoload=True , autoload_with=engine)

result = engine.execute(select(* [c for c in income_statement.columns]))

df = pd.DataFrame(result.fetchall(), columns= [c.name for c in income_statement.columns])
df

# %%
# conn = engine.connect()

# query = engine.select(['db_emplooyee'])

# %%
### This pd.read_sql_table are simple for of  read_sql_table

# %%
 
engine = create_engine('mysql+mysqlconnector://Eners:imDev888@127.0.0.1:3306/schema_001', echo=True)
df = pd.read_sql_table('income_statement', engine)

df

# df.query(_
# df.quer
# df.head()

# %%
len(df.query("date == 'December' "))
df.query("date == 'December' ")


# df

# %%
from sqlalchemy import create_engine , MetaData, Table, select
import mysql.connector as MySQLdb

engine = create_engine('mysql+mysqlconnector://Eners:imDev888@127.0.0.1:3306/schema_001', echo=True)

metadata = MetaData() 
conn = engine.connect()

income_statement = Table('income_statement' , metadata, autoload=True , autoload_with=engine) 

print(repr(metadata.tables['income_statement'])) 
#


# with engine.connect() as conn : 
#     query = select(['db_emplooyee'])
#     result = conn.execute(query)
    
#     headers = result.keys()
    
    
# conn = engine.connect()

# metadata.reflect(bind=engine)

# users_table = Table('Basee')

# engine.execute('SELECT * FROM db_emplooyee')

# %%
# %load_ext sql
# %sql mysql+mysqlconnector://Eners:imDev888@127.0.0.1:3306/schema_001
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: Eners@schema_001'

# %%
# %sql SELECT business_name FROM income_statement GROUP BY business_name
# Out:
#  * mysql+mysqlconnector://Eners:***@127.0.0.1:3306/schema_001
# 979 rows affected.
# [('Lehner-Ward',),
#  ('Schmeler-Gottlieb',),
#  ('Streich-Runte',),
#  ('Labadie-Hettinger',),
#  ('Schneider-Purdy',),
#  ('Feeney-Sanford',),
#  ('Schoen LLC',),
#  ('Zieme LLC',),
#  ('Klein Inc',),
#  ('Nolan and Sons',),
#  ('Hoppe-Wilkinson',),
#  ('Jerde, Strosin and Beier',),
#  ('Fisher-Bernhard',),
#  ('Powlowski, Cummings and Heathcote',),
#  ('Schumm Group',),
#  ('Weimann LLC',),
#  ('Bergnaum, Muller and Gerlach',),
#  ('Grady-Kuvalis',),
#  ('Volkman-Moen',),
#  ('Schaefer Group',),
#  ('Rau Group',),
#  ('Fisher LLC',),
#  ('Stamm LLC',),
#  ('Greenholt Inc',),
#  ('Walter, Kessler and Grady',),
#  ('Corwin-Bartell',),
#  ('Rau, Windler and Gerhold',),
#  ('Kling-Wiegand',),
#  ('Kessler and Sons',),
#  ('Flatley-VonRueden',),
#  ('Predovic, Johnston and Brown',),
#  ("Bradtke-O'Hara",),
#  ('Wuckert Group',),
#  ('Wisozk-Koss',),
#  ('Goyette, Hammes and Stokes',),
# ...

# %%
result = %sql SELECT * FROM income_statement  

df = result.DataFrame() 
df.head()
# Out:
#  * mysql+mysqlconnector://Eners:***@127.0.0.1:3306/schema_001
# 1000 rows affected.
#    id      business_name              manager      date  product_sales  \
# 0   1        Lehner-Ward      Jarib Welbelove  November          75239
# 1   2  Schmeler-Gottlieb    Gualterio Dorrins  February          71218
# 2   3      Streich-Runte       Dirk Woffenden      June          82950
# 3   4  Labadie-Hettinger  Thornton Lindenbaum       May          86211
# 4   5    Schneider-Purdy     Arny Cumberpatch       May          75824
#
#    service_revenue  raw_material  labor  salaries_wages  rent_exps  \
# 0            72731          7354   8501            7437       6316
# 1            82939          4273   7907            6801       6371
# 2            95349          5971   9321            7736       5202
# 3            84444          4393   7946            3576       9776
# 4            96866          7422   7034            3189       9008
#
# ...

# %%
df.loc[1]
# Out:
# id                                 2
# business_name      Schmeler-Gottlieb
# manager            Gualterio Dorrins
# date                        February
# product_sales                  71218
# service_revenue                82939
# raw_material                    4273
# labor                           7907
# salaries_wages                  6801
# rent_exps                       6371
# supplies_exps                   6241
# marketing_exps                  5092
# utillities_exps                 6202
# depreciation                    5332
# Name: 1, dtype: object
