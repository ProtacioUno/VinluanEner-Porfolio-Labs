# %%
# from sqlalchemy import create_engine
import MySQLdb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13528\3699050526.py in <module>
#       1 # from sqlalchemy import create_engine
# ----> 2 import MySQLdb
#
# ModuleNotFoundError: No module named 'MySQLdb'

# %%
username = 'Eners'
# password = 'imDev888'
password = "0912"; 
hostname = "127.0.0.1"
# hostname = "conn01"
port = 3306
database_name = 'basee'

# Create an engine to connect to the MySQL database
engine = create_engine(f'mysqldb://{username}:{password}@127.0.0.1:{port}/{database_name}')


# engine = create_engine('mysql://Eners:imDev888@localhost:3306/basee')
# engine = create_engin
# Out:
# ---------------------------------------------------------------------------
# NoSuchModuleError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5740\14415262.py in <module>
#       8
#       9 # Create an engine to connect to the MySQL database
# ---> 10 engine = create_engine(f'mysqldb://{username}:{password}@127.0.0.1:{port}/{database_name}')
#      11
#      12
#
# <string> in create_engine(url, **kwargs)
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     307                         stacklevel=3,
#     308                     )
# --> 309             return fn(*args, **kwargs)
#     310
#     311         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\engine\create.py in create_engine(url, **kwargs)
#     532     u, plugins, kwargs = u._instantiate_plugins(kwargs)
#     533
# --> 534     entrypoint = u._get_entrypoint()
#     535     dialect_cls = entrypoint.get_dialect_cls(u)
#     536
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\engine\url.py in _get_entrypoint(self)
#     653         else:
#     654             name = self.drivername.replace("+", ".")
# --> 655         cls = registry.load(name)
#     656         # check for legacy dialects that
#     657         # would return a module with 'dialect' as the
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\util\langhelpers.py in load(self, name)
#     342
#     343         raise exc.NoSuchModuleError(
# --> 344             "Can't load plugin: %s:%s" % (self.group, name)
#     345         )
#     346
#
# NoSuchModuleError: Can't load plugin: sqlalchemy.dialects:mysqldb

# %% [markdown]
# # Solo mysql.connector
# without mysql.connector

# %%
# import MySQLdb 


import mysql.connector as MySQLdb 
import pandas as pd
# import mysql.

connection = MySQLdb.connect(host='127.0.0.1', user='Eners', passwd='imDev888', db='schema_001')
cursor = connection.cursor()
## query 

cursor.execute('SELECT * FROM income_statement LIMIT 4') 
results = cursor.fetchall() 
df_result = pd.DataFrame(results, columns=income_statement.columns.keys() ) 
# the columns=income_statement.columns.keys() are connectortign to ro frame 
df_result
# Out:
#    id      business_name              manager      date  product_sales  \
# 0   1        Lehner-Ward      Jarib Welbelove  November          75239
# 1   2  Schmeler-Gottlieb    Gualterio Dorrins  February          71218
# 2   3      Streich-Runte       Dirk Woffenden      June          82950
# 3   4  Labadie-Hettinger  Thornton Lindenbaum       May          86211
#
#    service_revenue  raw_material  labor  salaries_wages  rent_exps  \
# 0            72731          7354   8501            7437       6316
# 1            82939          4273   7907            6801       6371
# 2            95349          5971   9321            7736       5202
# 3            84444          4393   7946            3576       9776
#
#    supplies_exps  marketing_exps  utillities_exps  depreciation
# 0           6651            5993             8487          7709
# 1           6241            5092             6202          5332
# 2           9976            8050             9940          8153
# 3           7262            7997             7515          6864

# %% [markdown]
# ### THIS kind of query only accept if QUERY AND columns.keys are match by column lenght

# %%
def querys(querry) : 
    cursor = connection.cursor()
    cursor.execute(querry) 
    results = cursor.fetchall() 
    df_result = pd.DataFrame(results, columns=income_statement.columns.keys() ) 
    # the columns=income_statement.columns.keys() are connectortign to ro frame 
    display(df_result)
    
querys('SELECT * FROM income_statement LIMIT 4') 

    # THIS kind of query only accept if QUERY AND columns.keys are match by column lenght 
    #
# Out:
#    id      business_name              manager      date  product_sales  \
# 0   1        Lehner-Ward      Jarib Welbelove  November          75239
# 1   2  Schmeler-Gottlieb    Gualterio Dorrins  February          71218
# 2   3      Streich-Runte       Dirk Woffenden      June          82950
# 3   4  Labadie-Hettinger  Thornton Lindenbaum       May          86211
#
#    service_revenue  raw_material  labor  salaries_wages  rent_exps  \
# 0            72731          7354   8501            7437       6316
# 1            82939          4273   7907            6801       6371
# 2            95349          5971   9321            7736       5202
# 3            84444          4393   7946            3576       9776
#
#    supplies_exps  marketing_exps  utillities_exps  depreciation
# 0           6651            5993             8487          7709
# 1           6241            5092             6202          5332
# 2           9976            8050             9940          8153
# 3           7262            7997             7515          6864

# %% [markdown]
# # CREAT_ENGINE

# %%
from sqlalchemy import create_engine, MetaData, Table, select
## this this sqlalchemy.create_engine but cannow accept create_engine only 

engine = create_engine('mysql+mysqlconnector://Eners:imDev888@127.0.0.1:3306/schema_001', echo=True)
metadata = MetaData() 


income_statement = Table('income_statement' , metadata , autoload=True , autoload_with=engine)

print(repr (metadata.tables['income_statement']) )  

# (n) print(type(MetaData())) 
# print()
# Out:
# 2024-02-18 14:29:25,694 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2024-02-18 14:29:25,694 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-02-18 14:29:25,694 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2024-02-18 14:29:25,694 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-02-18 14:29:25,709 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2024-02-18 14:29:25,709 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-02-18 14:29:25,709 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `income_statement`
# 2024-02-18 14:29:25,709 INFO sqlalchemy.engine.Engine [raw sql] {}
# Table('income_statement', MetaData(), Column('id', INTEGER(), table=<income_statement>), Column('business_name', VARCHAR(length=50), table=<income_statement>), Column('manager', VARCHAR(length=50), table=<income_statement>), Column('date', VARCHAR(length=9), table=<income_statement>), Column('product_sales', INTEGER(), table=<income_statement>), Column('service_revenue', INTEGER(), table=<income_statement>), Column('raw_material', INTEGER(), table=<income_statement>), Column('labor', INTEGER(), table=<income_statement>), Column('salaries_wages', INTEGER(), table=<income_statement>), Column('rent_exps', INTEGER(), table=<income_statement>), Column('supplies_exps', INTEGER(), table=<income_statement>), Column('marketing_exps', INTEGER(), table=<income_statement>), Column('utillities_exps', INTEGER(), table=<income_statement>), Column('depreciation', INTEGER(), table=<income_statement>), schema=None)

# %% [markdown]
# ### using sqr loop

# %%
from sqlalchemy import create_engine, MetaData, Table, select
## this this sqlalchemy.create_engine but cannow accept create_engine only 

engine = create_engine('mysql+mysqlconnector://Eners:imDev888@127.0.0.1:3306/schema_001', echo=True)
metadata = MetaData() 

income_statement = Table('income_statement' , metadata , autoload=True , autoload_with=engine)

result = engine.execute(select(* [c for c in income_statement.columns]))

df = pd.DataFrame(result.fetchall(), columns= [c.name for c in income_statement.columns])
df
# Out:
# 2024-02-18 14:29:28,603 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2024-02-18 14:29:28,603 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-02-18 14:29:28,616 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2024-02-18 14:29:28,616 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-02-18 14:29:28,619 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2024-02-18 14:29:28,619 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-02-18 14:29:28,619 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `income_statement`
# 2024-02-18 14:29:28,619 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-02-18 14:29:28,635 INFO sqlalchemy.engine.Engine SELECT income_statement.id, income_statement.business_name, income_statement.manager, income_statement.date, income_statement.product_sales, income_statement.service_revenue, income_statement.raw_material, income_statement.labor, income_statement.salaries_wages, income_statement.rent_exps, income_statement.supplies_exps, income_statement.marketing_exps, income_statement.utillities_exps, income_statement.depreciation
# FROM income_statement
# 2024-02-18 14:29:28,635 INFO sqlalchemy.engine.Engine [generated in 0.00192s] {}
#        id                    business_name              manager       date  \
# 0       1                      Lehner-Ward      Jarib Welbelove   November
# 1       2                Schmeler-Gottlieb    Gualterio Dorrins   February
# 2       3                    Streich-Runte       Dirk Woffenden       June
# 3       4                Labadie-Hettinger  Thornton Lindenbaum        May
# 4       5                  Schneider-Purdy     Arny Cumberpatch        May
# ..    ...                              ...                  ...        ...
# 995   996        Mertz, Wisoky and Reichel         Ivette Neame      March
# 996   997                   Maggio-Strosin      Caren Lightwing     August
# 997   998                  Powlowski Group        Dar Blockwell  September
# 998   999                Quitzon-Wilderman  Viviene Tittershill   February
# 999  1000  Bergnaum, Gusikowski and Harvey     Suzann Leadstone  September
#
#      product_sales  service_revenue  raw_material  labor  salaries_wages  \
# 0            75239            72731          7354   8501            7437
# 1            71218            82939          4273   7907            6801
# 2            82950            95349          5971   9321            7736
# 3            86211            84444          4393   7946            3576
# 4            75824            96866          7422   7034            3189
# ..             ...              ...           ...    ...             ...
# 995          80980            93597          6290   6323            4526
# 996          78278            91679          4154   6324            4663
# 997          75788            92401          7446   9507            6767
# 998          89017            70701          6305   7792            4066
# 999          92987            95876          5085   8402            4172
#
#      rent_exps  supplies_exps  marketing_exps  utillities_exps  depreciation
# 0         6316           6651            5993             8487          7709
# 1         6371           6241            5092             6202          5332
# 2         5202           9976            8050             9940          8153
# 3         9776           7262            7997             7515          6864
# 4         9008           9042            5223             9344          7639
# ..         ...            ...             ...              ...           ...
# 995       5508           7914            5678             5857          5329
# 996       6130           6262            6212             5064          8207
# 997       8603           9798            8943             7657          5458
# 998       5389           6918            9430             9906          7328
# 999       7933           7903            9849             6636          6291
#
# [1000 rows x 14 columns]

# %%
# conn = engine.connect()

# query = engine.select(['db_emplooyee'])

# %%
### This pd.read_sql_table are simple for of  read_sql_table

# %%
 
engine = create_engine('mysql+mysqlconnector://Eners:imDev888@127.0.0.1:3306/schema_001', echo=True)
df = pd.read_sql_table('income_statement', engine)

df

# df.query(_
# df.quer
# df.head()
# Out:
# 2024-02-18 14:31:10,512 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2024-02-18 14:31:10,521 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-02-18 14:31:10,521 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2024-02-18 14:31:10,529 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-02-18 14:31:10,529 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2024-02-18 14:31:10,529 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-02-18 14:31:10,529 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `schema_001`
# 2024-02-18 14:31:10,529 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-02-18 14:31:10,544 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `schema_001`
# 2024-02-18 14:31:10,544 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-02-18 14:31:10,544 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `income_statement`
# 2024-02-18 14:31:10,544 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-02-18 14:31:10,560 INFO sqlalchemy.engine.Engine SELECT income_statement.id, income_statement.business_name, income_statement.manager, income_statement.date, income_statement.product_sales, income_statement.service_revenue, income_statement.raw_material, income_statement.labor, income_statement.salaries_wages, income_statement.rent_exps, income_statement.supplies_exps, income_statement.marketing_exps, income_statement.utillities_exps, income_statement.depreciation
# FROM income_statement
# 2024-02-18 14:31:10,560 INFO sqlalchemy.engine.Engine [generated in 0.00276s] {}
#        id                    business_name              manager       date  \
# 0       1                      Lehner-Ward      Jarib Welbelove   November
# 1       2                Schmeler-Gottlieb    Gualterio Dorrins   February
# 2       3                    Streich-Runte       Dirk Woffenden       June
# 3       4                Labadie-Hettinger  Thornton Lindenbaum        May
# 4       5                  Schneider-Purdy     Arny Cumberpatch        May
# ..    ...                              ...                  ...        ...
# 995   996        Mertz, Wisoky and Reichel         Ivette Neame      March
# 996   997                   Maggio-Strosin      Caren Lightwing     August
# 997   998                  Powlowski Group        Dar Blockwell  September
# 998   999                Quitzon-Wilderman  Viviene Tittershill   February
# 999  1000  Bergnaum, Gusikowski and Harvey     Suzann Leadstone  September
#
#      product_sales  service_revenue  raw_material  labor  salaries_wages  \
# 0            75239            72731          7354   8501            7437
# 1            71218            82939          4273   7907            6801
# 2            82950            95349          5971   9321            7736
# 3            86211            84444          4393   7946            3576
# 4            75824            96866          7422   7034            3189
# ..             ...              ...           ...    ...             ...
# 995          80980            93597          6290   6323            4526
# 996          78278            91679          4154   6324            4663
# 997          75788            92401          7446   9507            6767
# 998          89017            70701          6305   7792            4066
# 999          92987            95876          5085   8402            4172
#
#      rent_exps  supplies_exps  marketing_exps  utillities_exps  depreciation
# 0         6316           6651            5993             8487          7709
# 1         6371           6241            5092             6202          5332
# 2         5202           9976            8050             9940          8153
# 3         9776           7262            7997             7515          6864
# 4         9008           9042            5223             9344          7639
# ..         ...            ...             ...              ...           ...
# 995       5508           7914            5678             5857          5329
# 996       6130           6262            6212             5064          8207
# 997       8603           9798            8943             7657          5458
# 998       5389           6918            9430             9906          7328
# 999       7933           7903            9849             6636          6291
#
# [1000 rows x 14 columns]

# %%
df.query('')
# Out:
#    id business_name          manager      date  product_sales  \
# 0   1   Lehner-Ward  Jarib Welbelove  November          75239
#
#    service_revenue  raw_material  labor  salaries_wages  rent_exps  \
# 0            72731          7354   8501            7437       6316
#
#    supplies_exps  marketing_exps  utillities_exps  depreciation
# 0           6651            5993             8487          7709

# %%
from sqlalchemy import create_engine , MetaData, Table, select
import mysql.connector as MySQLdb

engine = create_engine('mysql+mysqlconnector://Eners:imDev888@127.0.0.1:3306/basee', echo=True)

metadata = MetaData() 
conn = engine.connect()

# tb_emplooyee = Table('db_emplooyee' , metadata, autoload=True , autoload_with=engine) 

print(repr(metadata.tables['income_statement'])) 
#



# with engine.connect() as conn : 
#     query = select(['db_emplooyee'])
#     result = conn.execute(query)
    
#     headers = result.keys()
    
    
# conn = engine.connect()

# metadata.reflect(bind=engine)

# users_table = Table('Basee')

# engine.execute('SELECT * FROM db_emplooyee')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     207         try:
# --> 208             raise exception
#     209         finally:
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     255
# --> 256         return _ConnectionRecord(self)
#     257
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     370         if connect:
# --> 371             self.__connect()
#     372         self.finalize_callback = deque()
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     665             with util.safe_reraise():
# --> 666                 pool.logger.debug("Error on connect(): %s", e)
#     667         else:
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     207         try:
# --> 208             raise exception
#     209         finally:
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     660             self.starttime = time.time()
# --> 661             self.dbapi_connection = connection = pool._invoke_creator(self)
#     662             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     589                         return connection
# --> 590             return dialect.connect(*cargs, **cparams)
#     591
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     596         # inherits the docstring from interfaces.Dialect.connect
# --> 597         return self.dbapi.connect(*cargs, **cparams)
#     598
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
#     176         return CMySQLConnection(*args, **kwargs)
# --> 177     return MySQLConnection(*args, **kwargs)
#     178 Connect = connect  # pylint: disable=C0103
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\mysql\connector\connection.py in __init__(self, *args, **kwargs)
#     103             try:
# --> 104                 self.connect(**kwargs)
#     105             except:
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\mysql\connector\abstracts.py in connect(self, **kwargs)
#     780         self.disconnect()
# --> 781         self._open_connection()
#     782         # Server does not allow to run any other statement different from ALTER
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\mysql\connector\connection.py in _open_connection(self)
#     287                           self._database, self._client_flags, self._charset_id,
# --> 288                           self._ssl, self._conn_attrs)
#     289             self.set_converter_class(self._converter_class)
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\mysql\connector\connection.py in _do_auth(self, username, password, database, client_flags, charset, ssl_options, conn_attrs)
#     207         self._socket.send(packet)
# --> 208         self._auth_switch_request(username, password)
#     209
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\mysql\connector\connection.py in _auth_switch_request(self, username, password)
#     251         elif packet[4] == 255:
# --> 252             raise errors.get_exception(packet)
#     253         return None
#
# ProgrammingError: 1049 (42000): Unknown database 'basee'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5740\1431897539.py in <module>
#       5
#       6 metadata = MetaData()
# ----> 7 conn = engine.connect()
#       8
#       9 # tb_emplooyee = Table('db_emplooyee' , metadata, autoload=True , autoload_with=engine)
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3232         """
#    3233
# -> 3234         return self._connection_cls(self, close_with_result=close_with_result)
#    3235
#    3236     @util.deprecated(
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3311
#    3312         """
# -> 3313         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3314
#    3315
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3282             if connection is None:
#    3283                 Connection._handle_dbapi_exception_noconnection(
# -> 3284                     e, dialect, self
#    3285                 )
#    3286             else:
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2116         elif should_wrap:
#    2117             util.raise_(
# -> 2118                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2119             )
#    2120         else:
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206
#     207         try:
# --> 208             raise exception
#     209         finally:
#     210             # credit to
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3278         dialect = self.dialect
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#    3282             if connection is None:
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     308
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#     312     def _return_conn(self, record):
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     866     def _checkout(cls, pool, threadconns=None, fairy=None):
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#     870             fairy._pool = pool
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     474     @classmethod
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#     478             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144             except:
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#     148             return self._do_get()
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      70                 compat.raise_(
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#      74         else:
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206
#     207         try:
# --> 208             raise exception
#     209         finally:
#     210             # credit to
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141         if self._inc_overflow():
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#     145                 with util.safe_reraise():
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     254         """Called by subclasses to create a new ConnectionRecord."""
#     255
# --> 256         return _ConnectionRecord(self)
#     257
#     258     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     369         self.__pool = pool
#     370         if connect:
# --> 371             self.__connect()
#     372         self.finalize_callback = deque()
#     373
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     664         except Exception as e:
#     665             with util.safe_reraise():
# --> 666                 pool.logger.debug("Error on connect(): %s", e)
#     667         else:
#     668             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      70                 compat.raise_(
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#      74         else:
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206
#     207         try:
# --> 208             raise exception
#     209         finally:
#     210             # credit to
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     659         try:
#     660             self.starttime = time.time()
# --> 661             self.dbapi_connection = connection = pool._invoke_creator(self)
#     662             pool.logger.debug("Created new connection %r", connection)
#     663             self.fresh = True
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     588                     if connection is not None:
#     589                         return connection
# --> 590             return dialect.connect(*cargs, **cparams)
#     591
#     592         creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     595     def connect(self, *cargs, **cparams):
#     596         # inherits the docstring from interfaces.Dialect.connect
# --> 597         return self.dbapi.connect(*cargs, **cparams)
#     598
#     599     def create_connect_args(self, url):
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
#     175     if HAVE_CEXT and not use_pure:
#     176         return CMySQLConnection(*args, **kwargs)
# --> 177     return MySQLConnection(*args, **kwargs)
#     178 Connect = connect  # pylint: disable=C0103
#     179
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\mysql\connector\connection.py in __init__(self, *args, **kwargs)
#     102         if kwargs:
#     103             try:
# --> 104                 self.connect(**kwargs)
#     105             except:
#     106                 # Tidy-up underlying socket on failure
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\mysql\connector\abstracts.py in connect(self, **kwargs)
#     779
#     780         self.disconnect()
# --> 781         self._open_connection()
#     782         # Server does not allow to run any other statement different from ALTER
#     783         # when user's password has been expired.
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\mysql\connector\connection.py in _open_connection(self)
#     286             self._do_auth(self._user, self._password,
#     287                           self._database, self._client_flags, self._charset_id,
# --> 288                           self._ssl, self._conn_attrs)
#     289             self.set_converter_class(self._converter_class)
#     290             if self._client_flags & ClientFlag.COMPRESS:
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\mysql\connector\connection.py in _do_auth(self, username, password, database, client_flags, charset, ssl_options, conn_attrs)
#     206             conn_attrs=conn_attrs)
#     207         self._socket.send(packet)
# --> 208         self._auth_switch_request(username, password)
#     209
#     210         if not (client_flags & ClientFlag.CONNECT_WITH_DB) and database:
#
# ~\anaconda3\envs\Pythoink\lib\site-packages\mysql\connector\connection.py in _auth_switch_request(self, username, password)
#     250             return self._handle_ok(packet)
#     251         elif packet[4] == 255:
# --> 252             raise errors.get_exception(packet)
#     253         return None
#     254
#
# ProgrammingError: (mysql.connector.errors.ProgrammingError) 1049 (42000): Unknown database 'basee'
# (Background on this error at: https://sqlalche.me/e/14/f405)
